# %%
from PosSelect_Functions_Old import *
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import gaussian_kde
import pandas as pd
import numpy as np
import copy
import seaborn as sns
from scipy.stats import mannwhitneyu as mwu
from scipy.stats import ttest_ind
from scipy.stats import ttest_rel
from statsmodels.stats.multitest import fdrcorrection
from scipy.stats import wilcoxon
from scipy.optimize import curve_fit
from scipy.stats import fisher_exact

hfont = {'fontname':'Arial'}
plt.rcParams["font.family"] = "Arial"

#Code borrowed heavily from here: https://stackoverflow.com/questions/62375034/find-non-overlapping-area-between-two-kde-plots
plt.rcParams.update(
    {"text.usetex": False}
)

#Define a logarithmic function to fit to the data
def plot_stuff(df, title, xlabel, ylabel):
    def func(x, a, c, d):
        return a + d*np.log(x + c)

    #Fit said function
    popt, pcov = curve_fit(func, xdata=df["AF bin"], ydata=df["Alpha"], maxfev = 100000)
    sns.scatterplot(x=df["AF bin"], y=df["Alpha"])
    xx = np.linspace(0.1, 1, 100)
    yy = func(xx, *popt)
    plt.title(title, size = 18)
    plt.xlabel(xlabel, size = 15)
    plt.ylabel(ylabel, size = 15)
    plt.plot(xx, yy)
# Out:
# C:\Users\astar\anaconda3\Lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
v = pd.read_csv("Fixed_Mmd.Ready.mm39.bed", sep = "\t", header = None)
v["Position"] = v[0] + ":" + v[2].astype(str)
v.columns = [0, 1, 2, "Domesticus", "Musculus", "Castaneus", "Spretus", "Caroli", "Pahari", "Derived", "PhyloP447", "NearestGene", "NearestDist", "SpecSup447", "Position"]
v = v.drop_duplicates("Position")
v = v[["Position", "Domesticus", "Musculus", "Castaneus", "Spretus", "Caroli", "Pahari", "Derived", "PhyloP447", "NearestGene", "NearestDist", "SpecSup447"]].copy()

v = v[v["PhyloP447"] != "."]
v = v[v["SpecSup447"] != "."]
v = v[v["NearestGene"] != "."]

v["PhyloP447"] = v["PhyloP447"].astype(float)
v["SpecSup447"] = v["SpecSup447"].astype(float)

vv = pd.read_csv("Poly_Mmd.Ready.mm39.bed", sep = "\t", header = None)

vv["Position"] = vv[0] + ":" + vv[2].astype(str)
vv.columns = [0, 1, 2, "MajorAllele", "MinorAllele", "MAFMaxAcrossAncestry", "DerivedAllele", "UnfoldedMAF", "MusculusReference", "Spretus", "Caroli", "Pahari", "DerivedFromSubspecies", "PhyloP447", "NearestGene", "NearestDist", "SpecSup447", "Position"]
vv = vv.drop_duplicates("Position")
vv = vv[["Position", "MajorAllele", "MinorAllele", "MAFMaxAcrossAncestry", "DerivedAllele", "UnfoldedMAF", "MusculusReference", "Spretus", "Caroli", "Pahari", "DerivedFromSubspecies", "PhyloP447", "NearestGene", "NearestDist", "SpecSup447"]].copy()

vv = vv[vv["PhyloP447"] != "."]
vv = vv[vv["SpecSup447"] != "."]
vv = vv[vv["NearestGene"] != "."]

vv["PhyloP447"] = vv["PhyloP447"].astype(float)
vv["SpecSup447"] = vv["SpecSup447"].astype(float)

v = v[v["Derived"].isin(["MusDer"])]
vv = vv[~vv["DerivedAllele"].isin(["Amb"])]

v.index = v["Position"]
vv.index = vv["Position"]

v = v[~v["Position"].isin(vv["Position"])]

vv = vv[(vv["UnfoldedMAF"] < 0.9) & (vv["UnfoldedMAF"] > 0.1)]
# Out:
# C:\Users\astar\AppData\Local\Temp\ipykernel_13496\1958018314.py:1: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   v = pd.read_csv("Fixed_Mmd.Ready.mm39.bed", sep = "\t", header = None)
# C:\Users\astar\AppData\Local\Temp\ipykernel_13496\1958018314.py:14: DtypeWarning: Columns (13) have mixed types. Specify dtype option on import or set low_memory=False.
#   vv = pd.read_csv("Poly_Mmd.Ready.mm39.bed", sep = "\t", header = None)

# %%
v_vep = pd.read_csv("Fixed_Mmd_AllVEPs.txt", sep = "\t").set_index("Position")
vv_vep = pd.read_csv("Poly_Mmd_AllVEPs.txt", sep = "\t").set_index("Position")

fixed_syn = list(v_vep[v_vep["Effect"].isin(["Syn"])].index)
poly_syn = list(vv_vep[vv_vep["Effect"].isin(["Syn"])].index)

# %%
pli = pd.read_csv("gnomad.v4.1.constraint_metrics.tsv", sep = "\t")
pli = pli.dropna()
pli = pli[pli["lof.pLI"] > 0.9]
keep_pli = pli["gene"]

# %%
fixed_mis = list(v_vep[v_vep["Effect"].isin(["Mis"])].index)
poly_mis = list(vv_vep[vv_vep["Effect"].isin(["Mis"])].index)

# %%
orthos = pd.read_csv("Alecto_Musculus_Homo_Orthos.txt", sep = ',')
orthos = orthos.dropna()
orthos = orthos[(orthos["Mouse homology type"] == "ortholog_one2one") & (orthos["Megabat homology type"] == "ortholog_one2one")]
orthos = orthos.drop_duplicates("Gene stable ID")

orth2 = pd.read_csv("Orthologs_HumMouseMarm.txt", sep = "\t")
orth2 = orth2[["Gene stable ID", "Gene name"]]
orthos = orthos.set_index("Gene stable ID").join(orth2.set_index("Gene stable ID"))

v_use = v[v["NearestGene"].isin(orthos["Mouse gene name"])]
vv_use = vv[vv["NearestGene"].isin(orthos["Mouse gene name"])]

# %%
fixed_mis
# Out:
# ['chr5:139702151',
#  'chr5:45880451',
#  'chr5:87388634',
#  'chr5:4127258',
#  'chr5:121956294',
#  'chr5:61967434',
#  'chr5:72816090',
#  'chr5:109304746',
#  'chr5:140666562',
#  'chr5:34022042',
#  'chr5:86185353',
#  'chr5:32985134',
#  'chr5:124850923',
#  'chr5:65947850',
#  'chr5:129631509',
#  'chr5:139136038',
#  'chr4:152470419',
#  'chr5:137760723',
#  'chr5:35746541',
#  'chr5:88430358',
#  'chr5:77039485',
#  'chr5:124254882',
#  'chr5:138281331',
#  'chr5:6820900',
#  'chr5:92105457',
#  'chr5:123295534',
#  'chr5:142881040',
#  'chr5:115608973',
#  'chr5:48539208',
#  'chr5:145223167',
#  'chr5:77018393',
#  'chr5:5470112',
#  'chr5:96106548',
#  'chr4:156077036',
#  'chr5:150465734',
#  'chr5:137311717',
#  'chr5:137074383',
#  'chr5:150472229',
#  'chr5:130306035',
#  'chr4:155213173',
#  'chr5:24750350',
#  'chr5:105472964',
#  'chr5:4120489',
#  'chr5:120651279',
#  'chr5:100954674',
#  'chr5:137472434',
#  'chr5:108792446',
#  'chr5:129683553',
#  'chr5:113912003',
#  'chr5:123392715',
#  'chr5:137398250',
#  'chr5:8788756',
#  'chr5:77049895',
#  'chr5:8787731',
#  'chr5:124400972',
#  'chr5:150460453',
#  'chr6:5158225',
#  'chr5:144112015',
#  'chr6:3476028',
#  'chr5:115617723',
#  'chr5:64269414',
#  'chr4:152217397',
#  'chr5:120761643',
#  'chr4:150523844',
#  'chr4:156302310',
#  'chr6:14719326',
#  'chr5:137519231',
#  'chr5:138340895',
#  'chr5:31645327',
#  'chr5:74766846',
#  'chr4:155091472',
#  'chr5:112451816',
#  'chr5:67555607',
#  'chr4:156306370',
#  'chr4:150281872',
#  'chr5:17020713',
#  'chr5:93419137',
#  'chr5:4074105',
#  'chr4:156302341',
#  'chr5:112503224',
#  'chr5:110392401',
#  'chr5:21951048',
#  'chr6:5115163',
#  'chr5:86206083',
#  'chr5:65111950',
#  'chr5:129774981',
#  'chr5:53020976',
#  'chr5:54268440',
#  'chr5:118880655',
#  'chr4:156281807',
#  'chr5:123312496',
#  'chr5:137777295',
#  'chr5:123935769',
#  'chr5:114597008',
#  'chr5:108820236',
#  'chr4:155733282',
#  'chr5:36362919',
#  'chr4:155876534',
#  'chr5:34796622',
#  'chr5:108821421',
#  'chr5:52533916',
#  'chr5:33306273',
#  'chr5:8862655',
#  'chr4:156281805',
#  'chr4:155941242',
#  'chr5:144942758',
#  'chr5:14572180',
#  'chr5:122782230',
#  'chr4:156306379',
#  'chr4:155085055',
#  'chr5:108791129',
#  'chr6:23001873',
#  'chr5:96106556',
#  'chr5:23705733',
#  'chr5:34022010',
#  'chr4:151018863',
#  'chr5:45741932',
#  'chr6:30626323',
#  'chr5:92321833',
#  'chr4:154338695',
#  'chr5:30521745',
#  'chr5:137377222',
#  'chr5:31130917',
#  'chr5:75767921',
#  'chr5:87484694',
#  'chr5:108827389',
#  'chr5:53222866',
#  'chr5:110801504',
#  'chr5:118332697',
#  'chr5:54275698',
#  'chr5:21508229',
#  'chr4:155335451',
#  'chr5:143887128',
#  'chr5:103964097',
#  'chr5:35256584',
#  'chr5:17683730',
#  'chr5:134232175',
#  'chr5:21604772',
#  'chr5:38477623',
#  'chr5:125492078',
#  'chr5:67143782',
#  'chr5:63951648',
#  'chr5:109600903',
#  'chr5:44202913',
#  'chr5:36362472',
#  'chr5:73114788',
#  'chr5:110938736',
#  'chr5:109445376',
#  'chr5:127694372',
#  'chr5:31644733',
#  'chr5:31130979',
#  'chr5:105266317',
#  'chr5:100944559',
#  'chr5:86185740',
#  'chr5:120767732',
#  'chr4:155945436',
#  'chr5:135994592',
#  'chr5:121990712',
#  'chr5:109321686',
#  'chr5:67190489',
#  'chr5:113332327',
#  'chr6:3373779',
#  'chr5:36362319',
#  'chr4:155916995',
#  'chr5:30515893',
#  'chr6:23000426',
#  'chr5:134250890',
#  'chr5:122247279',
#  'chr5:145307511',
#  'chr5:107869553',
#  'chr5:143701030',
#  'chr4:156306779',
#  'chr5:124398257',
#  'chr5:138560807',
#  'chr6:18434331',
#  'chr5:112597701',
#  'chr5:34791263',
#  'chr5:143274514',
#  'chr5:110385966',
#  'chr5:140656234',
#  'chr5:137462524',
#  'chr4:156206828',
#  'chr5:136775903',
#  'chr5:150462140',
#  'chr5:142460178',
#  'chr5:89593173',
#  'chr5:92103420',
#  'chr4:155876491',
#  'chr5:109304416',
#  'chr5:24748563',
#  'chr5:44172246',
#  'chr5:139400895',
#  'chr5:150491123',
#  'chr5:73460979',
#  'chr5:124866938',
#  'chr6:29159744',
#  'chr5:38370604',
#  'chr6:8667348',
#  'chr5:124807141',
#  'chr5:140654825',
#  'chr5:113933330',
#  'chr4:155526583',
#  'chr5:107655647',
#  'chr6:30626283',
#  'chr6:7998620',
#  'chr5:121658898',
#  'chr4:155507142',
#  'chr6:8013023',
#  'chr5:43846341',
#  'chr5:24796329',
#  'chr5:123646111',
#  'chr6:5254555',
#  'chr5:4096694',
#  'chr5:124256087',
#  'chr6:22959669',
#  'chr5:104240709',
#  'chr4:156307895',
#  'chr5:110029741',
#  'chr5:144112066',
#  'chr5:137734193',
#  'chr5:142757335',
#  'chr5:65963844',
#  'chr4:151018832',
#  'chr5:22124062',
#  'chr5:6821807',
#  'chr5:109240777',
#  'chr5:139147632',
#  'chr5:114497810',
#  'chr5:116295627',
#  'chr4:150205205',
#  'chr5:34852125',
#  'chr5:45880488',
#  'chr5:14861654',
#  'chr5:103716030',
#  'chr5:112985674',
#  'chr5:86479073',
#  'chr5:22265370',
#  'chr5:150971057',
#  'chr5:25578099',
#  'chr6:23001940',
#  'chr5:124832868',
#  'chr5:4096444',
#  'chr5:37579193',
#  'chr6:13602596',
#  'chr5:72434524',
#  'chr5:114270125',
#  'chr5:137465232',
#  'chr4:155153207',
#  'chr5:121576803',
#  'chr5:135378710',
#  'chr5:4010289',
#  'chr4:150523878',
#  'chr5:92103416',
#  'chr5:45884330',
#  'chr5:21604717',
#  'chr4:152270829',
#  'chr5:114303697',
#  'chr5:143922343',
#  'chr5:88615779',
#  'chr5:110799558',
#  'chr5:106785996',
#  'chr5:137465309',
#  'chr5:146677279',
#  'chr5:109239682',
#  'chr4:152136227',
#  'chr5:137523079',
#  'chr5:67190453',
#  'chr5:147806333',
#  'chr6:24566402',
#  'chr5:45880636',
#  'chr5:17580817',
#  'chr5:88475859',
#  'chr5:65963930',
#  'chr6:29471700',
#  'chr6:22145540',
#  'chr5:135378689',
#  'chr5:124880884',
#  'chr5:143230977',
#  'chr5:52525637',
#  'chr5:97235180',
#  'chr5:30815102',
#  'chr6:29505761',
#  'chr5:45880639',
#  'chr5:113331235',
#  'chr4:156322172',
#  'chr5:15825382',
#  'chr4:156077007',
#  'chr4:156119545',
#  'chr5:124802264',
#  'chr5:106786495',
#  'chr4:156047133',
#  'chr5:65963892',
#  'chr5:150459781',
#  'chr5:143488699',
#  'chr5:121798887',
#  'chr6:17287071',
#  'chr5:65964516',
#  'chr5:149151214',
#  'chr6:21968913',
#  'chr5:90652232',
#  'chr5:113425525',
#  'chr5:45829664',
#  'chr5:31684418',
#  'chr5:84298317',
#  'chr5:36361569',
#  'chr5:31362929',
#  'chr5:24649117',
#  'chr5:24709960',
#  'chr5:7355196',
#  'chr5:137608799',
#  'chr5:28371535',
#  'chr5:107655007',
#  'chr5:143702703',
#  'chr5:34164805',
#  'chr4:156302068',
#  'chr6:22016993',
#  'chr5:4064075',
#  'chr5:117422159',
#  'chr5:124679416',
#  'chr4:156309687',
#  'chr5:122926031',
#  'chr4:152608799',
#  'chr5:65540928',
#  'chr5:145716356',
#  'chr4:152438021',
#  'chr5:137463344',
#  'chr5:144111685',
#  'chr5:134245598',
#  'chr5:21203232',
#  'chr5:109883965',
#  'chr5:23953718',
#  'chr5:109824535',
#  'chr5:67142820',
#  'chr4:156303571',
#  'chr5:65963885',
#  'chr4:156306923',
#  'chr5:137212575',
#  'chr5:90647487',
#  'chr5:113332295',
#  'chr5:127437237',
#  'chr5:150459936',
#  'chr5:8578713',
#  'chr4:156261111',
#  'chr5:110029677',
#  'chr5:120671146',
#  'chr6:31540525',
#  'chr5:93100421',
#  'chr4:155897031',
#  'chr4:155007780',
#  'chr5:121054965',
#  'chr5:145179823',
#  'chr5:113331713',
#  'chr5:9043542',
#  'chr4:156306881',
#  'chr6:29475436',
#  'chr5:90717384',
#  'chr5:41975917',
#  'chr5:37336754',
#  'chr5:87238744',
#  'chr5:103932104',
#  'chr4:150068492',
#  'chr5:143834299',
#  'chr4:155946334',
#  'chr6:5240894',
#  'chr5:100947426',
#  'chr4:154956170',
#  'chr5:137434735',
#  'chr5:138297435',
#  'chr5:109508656',
#  'chr4:155906355',
#  'chr6:14717875',
#  'chr5:51615621',
#  'chr5:9562137',
#  'chr4:156110941',
#  'chr5:113330674',
#  'chr5:77429297',
#  'chr4:156255074',
#  'chr5:43997822',
#  'chr6:5115189',
#  'chr5:24595526',
#  'chr5:90679360',
#  'chr5:106785491',
#  'chr5:100531751',
#  'chr6:8427043',
#  'chr4:156322099',
#  'chr4:156308087',
#  'chr5:6821142',
#  'chr5:140550423',
#  'chr5:124838316',
#  'chr6:23002233',
#  'chr5:123400176',
#  'chr5:122267811',
#  'chr4:156307489',
#  'chr5:136594446',
#  'chr6:30630811',
#  'chr5:122489376',
#  'chr5:124716558',
#  'chr5:124722203',
#  'chr5:138562903',
#  'chr6:18230034',
#  'chr5:77004542',
#  'chr5:113332294',
#  'chr5:124118396',
#  'chr5:74556112',
#  'chr5:31224142',
#  'chr6:24500247',
#  'chr5:109238384',
#  'chr5:150441161',
#  'chr5:76378119',
#  'chr5:34787967',
#  'chr5:52533756',
#  'chr5:14589965',
#  'chr5:105162936',
#  'chr5:87388794',
#  'chr6:21970078',
#  'chr5:4096067',
#  'chr5:121657840',
#  'chr5:140593322',
#  'chr5:120952558',
#  'chr5:125507097',
#  'chr5:97603396',
#  'chr4:156076824',
#  'chr4:154125517',
#  'chr5:149376799',
#  'chr4:156119575',
#  'chr5:37471812',
#  'chr5:3655847',
#  'chr5:21495541',
#  'chr5:110804396',
#  'chr4:156301848',
#  'chr4:155876485',
#  'chr5:138188468',
#  'chr5:72412380',
#  'chr5:105266314',
#  'chr5:5637234',
#  'chr5:9027489',
#  'chr5:105959958',
#  'chr5:3609685',
#  'chr5:114598552',
#  'chr6:7864028',
#  'chr4:156259043',
#  'chr5:115066271',
#  'chr5:41973860',
#  'chr5:110255166',
#  'chr5:92474715',
#  'chr4:155526594',
#  'chr5:124807153',
#  'chr5:108309475',
#  'chr5:23729307',
#  'chr5:77415866',
#  'chr5:73275801',
#  'chr5:62803605',
#  'chr5:108829643',
#  'chr5:149130909',
#  'chr5:92540461',
#  'chr5:73254836',
#  'chr5:107945698',
#  'chr5:86383314',
#  'chr5:105122594',
#  'chr5:137622524',
#  'chr5:137855504',
#  'chr5:31075429',
#  'chr5:86964840',
#  'chr5:121577910',
#  'chr5:143862594',
#  'chr5:77164380',
#  'chr5:149151650',
#  'chr4:155095392',
#  'chr5:8025814',
#  'chr5:4105658',
#  'chr5:90949246',
#  'chr5:3743315',
#  'chr5:132287944',
#  'chr5:135589325',
#  'chr5:43978885',
#  'chr5:123838571',
#  'chr4:156258460',
#  'chr5:15785791',
#  'chr5:113021925',
#  'chr4:155854828',
#  'chr5:34022099',
#  'chr5:22308277',
#  'chr5:35033291',
#  'chr4:154074334',
#  'chr5:151485860',
#  'chr5:5707808',
#  'chr4:150989700',
#  'chr4:155718592',
#  'chr5:28173204',
#  'chr5:38370592',
#  'chr4:152393335',
#  'chr5:143188194',
#  'chr5:91236393',
#  'chr5:24754467',
#  'chr5:90622491',
#  'chr5:3656375',
#  'chr5:118864363',
#  'chr5:41978971',
#  'chr5:77018407',
#  'chr5:52953952',
#  'chr5:108764896',
#  'chr6:25688665',
#  'chr5:3901423',
#  'chr5:112597809',
#  'chr4:155545406',
#  'chr4:152367640',
#  'chr5:118340850',
#  'chr5:76757487',
#  'chr6:23001998',
#  'chr5:138165390',
#  'chr5:122242698',
#  'chr5:121991138',
#  'chr5:139346409',
#  'chr5:86185292',
#  'chr5:62996593',
#  'chr5:107581418',
#  'chr5:117643645',
#  'chr5:3720080',
#  'chr5:144146792',
#  'chr4:151019939',
#  'chr4:156257045',
#  'chr5:125201842',
#  'chr5:110275982',
#  'chr5:113957361',
#  'chr5:24907433',
#  'chr5:121639434',
#  'chr5:149130941',
#  'chr5:115417860',
#  'chr4:152608784',
#  'chr5:123295838',
#  'chr5:114497645',
#  'chr5:138606053',
#  'chr5:92540566',
#  'chr4:156261793',
#  'chr5:25515401',
#  'chr5:118005775',
#  'chr5:109240045',
#  'chr5:112598652',
#  'chr5:122579762',
#  'chr4:150988335',
#  'chr5:24604967',
#  'chr5:138269302',
#  'chr5:123639278',
#  'chr4:156301570',
#  'chr5:124453755',
#  'chr5:53221242',
#  'chr5:107582033',
#  'chr5:145736158',
#  'chr5:87398484',
#  'chr5:87398465',
#  'chr5:123619785',
#  'chr4:156217351',
#  'chr5:14570923',
#  'chr5:88652245',
#  'chr5:35745536',
#  'chr5:130306032',
#  'chr5:21535560',
#  'chr6:29736160',
#  'chr5:108879534',
#  'chr5:90740783',
#  'chr5:17011738',
#  'chr5:32986681',
#  'chr5:35758856',
#  'chr5:35199695',
#  'chr5:36222775',
#  'chr5:41977591',
#  'chr5:120758575',
#  'chr5:21124808',
#  'chr5:108794339',
#  'chr5:34979171',
#  'chr5:31363525',
#  'chr5:87961825',
#  'chr5:87402293',
#  'chr5:67557392',
#  'chr5:120946771',
#  'chr6:18103509',
#  'chr5:14589883',
#  'chr5:113339536',
#  'chr5:21837263',
#  'chr5:107655114',
#  'chr5:32985184',
#  'chr5:109445373',
#  'chr5:21991690',
#  'chr5:103704003',
#  'chr5:103124245',
#  'chr5:147403881',
#  'chr5:73481178',
#  'chr5:116426523',
#  'chr5:21961402',
#  'chr5:114084789',
#  'chr5:65084013',
#  'chr5:3743891',
#  'chr5:108719914',
#  'chr5:116582815',
#  'chr5:145101944',
#  'chr5:150585929',
#  'chr5:34237273',
#  'chr5:36642219',
#  'chr4:156303630',
#  'chr5:32988892',
#  'chr5:118886820',
#  'chr5:87074122',
#  'chr4:156284293',
#  'chr5:103137465',
#  'chr5:90623157',
#  'chr5:43861269',
#  'chr5:103247879',
#  'chr5:3729054',
#  'chr5:121000809',
#  'chr4:156303457',
#  'chr5:3913943',
#  'chr5:86810099',
#  'chr5:6822251',
#  'chr5:114081126',
#  'chr5:114951940',
#  'chr5:14732003',
#  'chr5:109238412',
#  'chr5:54275631',
#  'chr5:149502532',
#  'chr5:150472096',
#  'chr5:64056038',
#  'chr5:77454213',
#  'chr5:36362148',
#  'chr5:120952557',
#  'chr5:121639593',
#  'chr5:110028271',
#  'chr5:41952433',
#  'chr5:109234427',
#  'chr5:31027108',
#  'chr5:14728071',
#  'chr5:69723761',
#  'chr5:92425819',
#  'chr5:121474757',
#  'chr4:155177827',
#  'chr5:6822563',
#  'chr5:98646182',
#  'chr5:103797303',
#  'chr5:31074416',
#  'chr5:100526826',
#  'chr5:28180956',
#  'chr5:29429253',
#  'chr5:33547282',
#  'chr5:110225846',
#  'chr5:135093687',
#  'chr4:155868886',
#  'chr5:121923870',
#  'chr5:121966491',
#  'chr5:109825172',
#  'chr5:107652419',
#  'chr5:32988877',
#  'chr4:156263567',
#  'chr4:150523921',
#  'chr6:5007817',
#  'chr4:154117282',
#  'chr5:72716519',
#  'chr5:121998920',
#  'chr4:156253706',
#  'chr5:109508765',
#  'chr5:107525876',
#  'chr5:65963871',
#  'chr6:30612647',
#  'chr5:113933329',
#  'chr5:140703952',
#  'chr4:156284216',
#  'chr5:115687115',
#  'chr5:24704979',
#  'chr5:37331031',
#  'chr5:87990994',
#  'chr5:150465629',
#  'chr5:105229092',
#  'chr5:41975341',
#  'chr4:152131081',
#  'chr4:156303136',
#  'chr5:150460232',
#  'chr5:65948377',
#  'chr5:113240990',
#  'chr5:65083309',
#  'chr5:25504302',
#  'chr5:110527322',
#  'chr5:30639464',
#  'chr5:143274310',
#  'chr5:6820858',
#  'chr5:74358938',
#  'chr5:24648370',
#  'chr6:29452837',
#  'chr5:114911383',
#  'chr5:92552705',
#  'chr5:137454550',
#  'chr5:28182006',
#  'chr6:18408699',
#  'chr5:150472010',
#  'chr5:37084885',
#  'chr6:32028639',
#  'chr5:138269089',
#  'chr5:124811573',
#  'chr5:31693493',
#  'chr5:88649604',
#  'chr6:6956079',
#  'chr5:145227233',
#  'chr4:156309229',
#  'chr5:100954659',
#  'chr5:145132443',
#  'chr5:41989958',
#  'chr5:21203333',
#  'chr5:135084897',
#  'chr5:77429459',
#  'chr5:121639672',
#  'chr5:121948958',
#  'chr5:120670982',
#  'chr5:3881504',
#  'chr5:112518156',
#  'chr5:64435294',
#  'chr5:32471032',
#  'chr5:65233121',
#  'chr5:107768331',
#  'chr4:156263291',
#  'chr5:4012167',
#  'chr5:25515288',
#  'chr5:143275517',
#  'chr6:7998622',
#  'chr5:138340916',
#  'chr5:93190464',
#  'chr5:110275821',
#  'chr5:4025644',
#  'chr5:90666893',
#  'chr5:121516607',
#  'chr5:122538481',
#  'chr5:129937463',
#  'chr5:4111248',
#  'chr5:88703247',
#  'chr5:33826840',
#  'chr5:109239675',
#  'chr5:114749752',
#  'chr5:123400132',
#  'chr5:144111970',
#  'chr5:30619096',
#  'chr5:38371360',
#  'chr6:22999260',
#  'chr5:41974729',
#  'chr5:38360782',
#  'chr5:24745858',
#  'chr5:124405111',
#  'chr5:123296981',
#  'chr4:152067559',
#  'chr5:144111452',
#  'chr5:144112028',
#  'chr5:150462857',
#  'chr5:77452134',
#  'chr5:124118363',
#  'chr5:31074596',
#  'chr5:121917524',
#  'chr5:31347328',
#  'chr4:155154895',
#  'chr5:134962387',
#  'chr5:88649855',
#  'chr5:35028133',
#  'chr5:112502883',
#  'chr5:144112052',
#  'chr6:12554930',
#  'chr6:30615177',
#  'chr4:156256691',
#  'chr5:124842682',
#  'chr5:145138074',
#  'chr5:150465566',
#  'chr5:67142809',
#  'chr5:104242551',
#  'chr5:21476222',
#  'chr5:21604737',
#  'chr6:3967892',
#  'chr5:37317182',
#  'chr4:156261703',
#  'chr5:150472267',
#  'chr6:30129283',
#  'chr5:137766388',
#  'chr5:149150902',
#  'chr5:124842019',
#  'chr5:100949777',
#  'chr5:5299188',
#  'chr4:156100856',
#  'chr4:155008953',
#  'chr5:41976094',
#  'chr5:138340559',
#  'chr5:14725381',
#  'chr5:4096735',
#  'chr5:41978458',
#  'chr5:121658094',
#  'chr6:18268023',
#  'chr5:124453595',
#  'chr5:111434238',
#  'chr4:151017499',
#  'chr5:137204231',
#  'chr5:149146595',
#  'chr4:156302157',
#  'chr5:108309450',
#  'chr5:14719171',
#  'chr5:137444902',
#  'chr5:77025434',
#  'chr5:108995370',
#  'chr5:107651409',
#  'chr4:155007792',
#  'chr5:76784814',
#  'chr5:38388320',
#  'chr5:112510990',
#  'chr5:32986471',
#  'chr5:122469720',
#  'chr5:122573722',
#  'chr5:123059500',
#  'chr5:135754784',
#  'chr5:37506025',
#  'chr5:110384280',
#  'chr4:156216641',
#  'chr5:36362961',
#  'chr5:103982014',
#  'chr4:154126268',
#  'chr4:152212717',
#  'chr6:3967971',
#  'chr5:143828309',
#  'chr5:96703071',
#  'chr6:8175231',
#  'chr5:21203359',
#  'chr5:34484365',
#  'chr5:31074880',
#  'chr5:38941865',
#  'chr5:87737982',
#  'chr5:88127892',
#  'chr5:64331196',
#  'chr5:102700023',
#  'chr5:86183300',
#  'chr5:31805193',
#  'chr5:138560724',
#  'chr5:41976041',
#  'chr5:34480335',
#  'chr5:32985223',
#  'chr6:23097160',
#  'chr5:67132972',
#  'chr5:142458092',
#  'chr5:31075244',
#  'chr5:64055669',
#  'chr5:107651646',
#  'chr5:121784884',
#  'chr5:141938923',
#  'chr5:107269258',
#  'chr5:77004589',
#  'chr5:30403374',
#  'chr5:121010985',
#  'chr6:32035449',
#  'chr5:14590202',
#  'chr5:30830382',
#  'chr6:29474761',
#  'chr5:32979438',
#  'chr5:138454165',
#  'chr5:88256400',
#  'chr4:152136402',
#  'chr5:28175066',
#  'chr5:8208893',
#  'chr5:36971809',
#  'chr5:24738797',
#  'chr4:156132065',
#  'chr5:100944499',
#  'chr5:106605116',
#  'chr5:108589864',
#  'chr5:45682503',
#  'chr4:155924314',
#  'chr5:35198959',
#  'chr5:24010610',
#  'chr5:25455092',
#  'chr6:8510266',
#  'chr5:106785547',
#  'chr5:144112244',
#  'chr5:112598298',
#  'chr5:53993947',
#  'chr5:5634775',
#  'chr5:5675886',
#  'chr5:67175079',
#  'chr5:109445364',
#  'chr5:112841013',
#  'chr5:35237004',
#  'chr5:110275858',
#  'chr5:96744712',
#  'chr5:115723916',
#  'chr5:3674005',
#  'chr4:151096870',
#  'chr5:31246973',
#  'chr5:107065397',
#  'chr4:155735200',
#  'chr5:108995923',
#  'chr5:120766458',
#  'chr5:114857734',
#  'chr5:8025454',
#  'chr5:149650303',
#  'chr4:154120565',
#  'chr4:155740133',
#  'chr5:150466200',
#  'chr4:154942447',
#  'chr5:33829056',
#  'chr5:113339662',
#  'chr5:139697426',
#  'chr5:109239808',
#  'chr5:41990030',
#  'chr5:147403824',
#  'chr5:123588555',
#  'chr5:123639136',
#  'chr6:30585931',
#  'chr5:122007580',
#  'chr6:28419229',
#  'chr6:24796459',
#  'chr5:4012177',
#  'chr5:45882271',
#  'chr5:52973221',
#  'chr5:6820498',
#  'chr5:109144312',
#  'chr4:151125845',
#  'chr5:4105725',
#  'chr5:115617673',
#  'chr5:146147207',
#  'chr5:32986613',
#  'chr6:23409962',
#  'chr5:89982885',
#  'chr4:155739748',
#  'chr5:112598076',
#  'chr4:155947485',
#  'chr5:77430130',
#  'chr5:31362905',
#  'chr5:52533970',
#  'chr5:93098858',
#  'chr5:145174064',
#  'chr5:89982946',
#  'chr6:24556597',
#  'chr5:32984314',
#  'chr5:112503098',
#  'chr5:122246304',
#  'chr4:155906314',
#  'chr5:28176160',
#  'chr6:28445812',
#  'chr5:65963810',
#  'chr5:86644385',
#  'chr5:21101314',
#  'chr4:152371380',
#  'chr5:24758562',
#  'chr5:67188244',
#  'chr5:124811555',
#  'chr5:37332788',
#  'chr4:155906298',
#  'chr5:3716817',
#  'chr5:25519839',
#  'chr5:109702869',
#  'chr5:113330838',
#  'chr5:109823461',
#  'chr5:121005071',
#  'chr5:73816608',
#  'chr5:28172037',
#  'chr5:114597007',
#  'chr5:8848757',
#  'chr4:156050925',
#  'chr5:142173898',
#  'chr5:92410387',
#  'chr6:28244378',
#  'chr5:77049847',
#  'chr5:88652343',
#  'chr5:146784187',
#  'chr4:156110925',
#  'chr5:65137233',
#  'chr5:65947721',
#  'chr5:73786987',
#  'chr5:14571628',
#  'chr5:77164185',
#  'chr5:90949256',
#  'chr6:23097142',
#  'chr5:113422064',
#  'chr5:41978944',
#  'chr5:52976517',
#  'chr5:124531938',
#  'chr5:72681003',
#  'chr5:145810310',
#  'chr5:103931756',
#  'chr5:123588588',
#  'chr6:8457537',
#  'chr5:32986265',
#  'chr5:96748616',
#  'chr6:23097157',
#  'chr5:34012927',
#  'chr5:4010270',
#  'chr5:65111974',
#  'chr5:122507672',
#  'chr5:109823655',
#  'chr5:24920580',
#  'chr5:106784729',
#  'chr5:109441166',
#  'chr5:77024085',
#  'chr5:31711159',
#  'chr6:28526967',
#  'chr5:6821362',
#  'chr5:35005009',
#  'chr5:21506318',
#  'chr4:155906370',
#  'chr5:14719187',
#  'chr5:88430361',
#  'chr5:24646644',
#  'chr5:88119788',
#  'chr5:72453103',
#  ...]

# %%
v_mis = v[v["Position"].isin(fixed_mis)]
vv_mis = vv[vv["Position"].isin(poly_mis)]

v_mis
# Out:
#                       Position Domesticus              Musculus  \
# Position
# chr1:4089333      chr1:4089333          G  G,0.955,42;T,0.045,2
# chr1:4298829      chr1:4298829          C                     G
# chr1:4301292      chr1:4301292          T                     G
# chr1:4415076      chr1:4415076          C                     C
# chr1:4415085      chr1:4415085          C                     C
# ...                        ...        ...                   ...
# chrX:168102449  chrX:168102449          T                     T
# chrX:168560021  chrX:168560021          T                     T
# chrX:168560152  chrX:168560152          G                     G
# chrX:168699211  chrX:168699211          C                     C
# chrX:168709972  chrX:168709972          C                     C
#
#                          Castaneus Spretus Caroli Pahari Derived  PhyloP447  \
# Position
# chr1:4089333    T,0.65,13;G,0.35,7       T      T      T  MusDer      1.328
# chr1:4298829    G,0.75,15;C,0.25,5       G      G      G  MusDer      3.458
# chr1:4301292    T,0.45,9;G,0.55,11       G      G      G  MusDer      4.684
# chr1:4415076                     C       T      T      T  MusDer     -1.045
# chr1:4415085                     C       T      T      T  MusDer     -0.026
# ...                            ...     ...    ...    ...     ...        ...
# chrX:168102449                   T       C      C      T  MusDer      2.298
# chrX:168560021                   T       C      C      C  MusDer      0.165
# chrX:168560152                   G       A      A      A  MusDer     -0.453
# chrX:168699211                   C       A      A      A  MusDer      3.317
# chrX:168709972                   C       T      T      T  MusDer      2.070
#
#                   NearestGene  NearestDist  SpecSup447
# Position
# chr1:4089333              Rp1       340175       397.0
# chr1:4298829              Rp1       130679       427.0
# chr1:4301292              Rp1       128216       436.0
# chr1:4415076              Rp1        14432       442.0
# chr1:4415085              Rp1        14423       442.0
# ...                       ...          ...         ...
# chrX:168102449           Hccs            0       421.0
# chrX:168560021  4933400A11Rik         1591       130.0
# chrX:168560152  4933400A11Rik         1460       161.0
# chrX:168699211           Mid1        35589       435.0
# chrX:168709972           Mid1        46350       439.0
#
# [22806 rows x 12 columns]

# %%
v_use = v[v["Position"].isin(fixed_syn)]
vv_use = vv[vv["Position"].isin(poly_syn)]

alpha, to_plot = asymptotic_unfold_cutoff(v_use, vv_use, start = 0.1, dn_cut = 0.0001, to_plot_curve = False, cuttt = 0.6)
plot_stuff(to_plot, title = "Asymptotic for house mouse synonymous sites", ylabel = "$\\alpha_{Cons}$", xlabel = "Derived allele frequency bin")

# %%
v_vep = pd.read_csv("Fixed_Mmd_AllVEPs.txt", sep = "\t").set_index("Position")
vv_vep = pd.read_csv("Poly_Mmd_AllVEPs.txt", sep = "\t").set_index("Position")

fixed_mis = list(v_vep[v_vep["Effect"].isin(["Mis"])].index)
poly_mis = list(vv_vep[vv_vep["Effect"].isin(["Mis"])].index)

fixed_syn = list(v_vep[v_vep["Effect"].isin(["Syn"])].index)
poly_syn = list(vv_vep[vv_vep["Effect"].isin(["Syn"])].index)

fixed_3p = list(v_vep[v_vep["Effect"].isin(["3P"])].index)
poly_3p = list(vv_vep[vv_vep["Effect"].isin(["3P"])].index)

fixed_5p = list(v_vep[v_vep["Effect"].isin(["5P"])].index)
poly_5p = list(vv_vep[vv_vep["Effect"].isin(["5P"])].index)

fixed_nc = list(v_vep[v_vep["Effect"].isin(["NC"])].index)
poly_nc = list(vv_vep[vv_vep["Effect"].isin(["NC"])].index)

v_vep = 0
vv_vep = 0

#Chosen based on being number of rodents + 8
vv = vv[vv["SpecSup447"] > 61]
v = v[v["SpecSup447"] > 61]

# %%
toss = []
for i in np.unique(vv["NearestGene"]):
    if "H2-" in i:
        toss.append(i)
        
for i in np.unique(v["NearestGene"]):
    if "H2-" in i:
        toss.append(i)

v = v[~v["NearestGene"].isin(toss)]
vv = vv[~vv["NearestGene"].isin(toss)]

# %%
#For fair comparison with bat, only use 1-1 orthos and toss all nonsyn/syn sites
orthos = pd.read_csv("Alecto_Musculus_Homo_Orthos.txt", sep = ',')
orthos = orthos.dropna()
orthos = orthos[(orthos["Mouse homology type"] == "ortholog_one2one") & (orthos["Megabat homology type"] == "ortholog_one2one")]
orthos = orthos.drop_duplicates("Gene stable ID")

orth2 = pd.read_csv("Orthologs_HumMouseMarm.txt", sep = "\t")
orth2 = orth2[["Gene stable ID", "Gene name"]]
orthos = orthos.set_index("Gene stable ID").join(orth2.set_index("Gene stable ID"))

v_use = v[v["NearestGene"].isin(orthos["Mouse gene name"])]
vv_use = vv[vv["NearestGene"].isin(orthos["Mouse gene name"])]

v_use = v[v["Position"].isin(fixed_nc + fixed_3p + fixed_5p)]
vv_use = vv[vv["Position"].isin(poly_nc + poly_3p + poly_5p)]

v_use = v[~v["Position"].isin(fixed_syn)]
vv_use = vv[~vv["Position"].isin(poly_syn)]

# %%
alpha, to_plot = asymptotic_unfold_cutoff(v_use, vv_use, start = 0.1, dn_cut = 0.0001, to_plot_curve = False, cuttt = 0.6)
plot_stuff(to_plot, title = "Asymptotic for house mouse non-coding sites", ylabel = "$\\alpha_{Cons}$", xlabel = "Derived allele frequency bin")
print(alpha)
# Out:
# C:\Users\astar\anaconda3\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# 0.038108887653804095

# %%
alpha, to_plot = asymptotic_unfold_cutoff(v_use, vv_use, start = 0.1, dn_cut = 0.0001, to_plot_curve = False, cuttt = 0.95)
plot_stuff(to_plot, title = "Asymptotic for house mouse non-coding sites", ylabel = "$\\alpha_{Cons}$", xlabel = "Derived allele frequency bin")
print(alpha)
# Out:
# C:\Users\astar\anaconda3\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# 0.09394449381677168

# %%
for chrom in ["chr" + str(x) for x in range(1, 20)] + ["chrX"]:
    vk = v[(v["Chrom"] == chrom) & (v["Position"].isin(fixed_nc))].copy()
    vvk = vv[(vv["Chrom"] == chrom) & (vv["Position"].isin(poly_nc))]
    #vvk = vvk[(vvk["MAFMaxAcrossAncestry"] < 0.75) & (vvk["MAFMaxAcrossAncestry"] > 0.25)].copy()
    vvk = vvk[(vvk["UnfoldedMAF"] > 0.5)].copy()
    vvv = prepare_alpha(vk, vvk)
    
    yvals2 = [np.float64(j) for j in list(vvk["PhyloP447"])]
    yvals2.sort()
    cuttt = 0.95
    cutoff = yvals2[int(floor((len(yvals2)*cuttt)))]
    alpha = compute_alpha_cutoff(vvv, cutoff = cutoff)
    print(chrom, alpha[0], fisher_exact(alpha[-2]))
# Out:
# chr1 -0.05277228442808035 SignificanceResult(statistic=0.9495788930528014, pvalue=0.0014302441710086185)
# chr2 -0.0072855509112806915 SignificanceResult(statistic=0.9930841331636984, pvalue=0.6797394836799178)
# chr3 -0.021220716580020227 SignificanceResult(statistic=0.9792665872051739, pvalue=0.2368348414080718)
# chr4 -0.0537326595793578 SignificanceResult(statistic=0.9490510753509559, pvalue=0.005291909808818714)
# chr5 -0.03065899929526683 SignificanceResult(statistic=0.9705831026106794, pvalue=0.11620824135452343)
# chr6 0.0006357670714600694 SignificanceResult(statistic=1.0011201356022237, pvalue=0.9619321963237489)
# chr7 -0.05530362604180161 SignificanceResult(statistic=0.9484023039623914, pvalue=0.01410307955789733)
# chr8 -0.03318445735127007 SignificanceResult(statistic=0.9678260110048655, pvalue=0.10410827599983342)
# chr9 -0.017782166783108067 SignificanceResult(statistic=0.9823664160225904, pvalue=0.380468438789545)
# chr10 -0.0264297548295086 SignificanceResult(statistic=0.9744539900067292, pvalue=0.1785861442865027)
# chr11 -0.0514853004568423 SignificanceResult(statistic=0.9509472725148537, pvalue=0.016657930374061013)
# chr12 -0.001837366388288575 SignificanceResult(statistic=0.997995156225275, pvalue=0.9240906969619332)
# chr13 -0.0428277089765402 SignificanceResult(statistic=0.9589528507367335, pvalue=0.050022606466682266)
# chr14 -0.042208965470672655 SignificanceResult(statistic=0.9592630948949025, pvalue=0.04695596005056253)
# chr15 -0.030478944370850525 SignificanceResult(statistic=0.9703132641520557, pvalue=0.17203402342367485)
# chr16 -0.029334828980847383 SignificanceResult(statistic=0.971884395277389, pvalue=0.2018713403464692)
# chr17 0.018614051509181107 SignificanceResult(statistic=1.018739970601151, pvalue=0.45748208262214907)
# chr18 0.01778622437573979 SignificanceResult(statistic=1.0180286524047202, pvalue=0.43596723585843405)
# chr19 0.019634776553211886 SignificanceResult(statistic=1.019629628427532, pvalue=0.48509592023960174)
# chrX -0.01750054786693489 SignificanceResult(statistic=0.9834627593870784, pvalue=0.6254661162844926)

# %%
asymptotic_unfold_cutoff(v[(v["Chrom"] == "chr18") & (v["Position"].isin(fixed_nc))].copy(), vv[(vv["Chrom"] == "chr18") & (vv["Position"].isin(poly_nc))].copy(), start = 0.1, dn_cut = 0.0001, to_plot_curve = True, cuttt = 0.95)
# Out:
# (0.08926744859125235,
#     AF bin     Alpha  Cutoff         [[dc1, du1], [pc1, pu1]]  \
#  0     0.2 -0.192165   2.359  [[5434, 123067], [1983, 37683]]
#  1     0.3 -0.163841   2.329  [[5558, 122943], [1487, 28264]]
#  2     0.4 -0.187546   2.355   [[5452, 123049], [926, 17597]]
#  3     0.5 -0.098379   2.256   [[5878, 122623], [923, 17541]]
#  4     0.6  0.001271   2.168   [[6441, 122060], [709, 13483]]
#  5     0.7 -0.021530   2.190   [[6297, 122204], [665, 12645]]
#  6     0.8  0.037964   2.142   [[6651, 121850], [825, 15726]]
#  7     0.9  0.032380   2.144   [[6632, 121869], [759, 14426]]
#
#            [[dc2, du2], [pc2, pu2]]  Num Poly in Bin
#  0  [[5439, 123062], [1986, 37680]]            39666
#  1  [[5561, 122940], [1488, 28263]]            29751
#  2   [[5459, 123042], [927, 17596]]            18523
#  3   [[5884, 122617], [925, 17539]]            18464
#  4   [[6450, 122051], [713, 13479]]            14192
#  5   [[6305, 122196], [667, 12643]]            13310
#  6   [[6663, 121838], [828, 15723]]            16551
#  7   [[6639, 121862], [761, 14424]]            15185  )

# %%
asymptotic_unfold_cutoff(v, vv, start = 0.1, dn_cut = 0.0001, to_plot_curve = True, cuttt = 0.95)
# Out:
# C:\Users\astar\anaconda3\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# (0.08164697139961244,
#     AF bin     Alpha  Cutoff               [[dc1, du1], [pc1, pu1]]  \
#  0     0.2 -0.244547   2.515  [[138709, 3281360], [54204, 1030376]]
#  1     0.3 -0.153642   2.429   [[149149, 3270920], [38886, 739115]]
#  2     0.4 -0.089996   2.361   [[157517, 3262552], [24427, 464245]]
#  3     0.5 -0.052648   2.318   [[162834, 3257235], [24209, 460080]]
#  4     0.6 -0.019681   2.278   [[167782, 3252287], [17918, 340586]]
#  5     0.7  0.011221   2.242   [[172737, 3247332], [16616, 315967]]
#  6     0.8  0.042593   2.208   [[178143, 3241926], [19917, 378553]]
#  7     0.9  0.064120   2.186   [[182093, 3237976], [19166, 364285]]
#
#                  [[dc2, du2], [pc2, pu2]]  Num Poly in Bin
#  0  [[138822, 3281247], [54254, 1030326]]          1084580
#  1   [[149281, 3270788], [38910, 739091]]           778001
#  2   [[157629, 3262440], [24452, 464220]]           488672
#  3   [[162950, 3257119], [24230, 460059]]           484289
#  4   [[167916, 3252153], [17929, 340575]]           358504
#  5   [[172879, 3247190], [16635, 315948]]           332583
#  6   [[178313, 3241756], [19933, 378537]]           398470
#  7   [[182258, 3237811], [19196, 364255]]           383451  )

# %%
asymptotic_unfold_cutoff(v[v["Position"].isin(fixed_nc)], vv[vv["Position"].isin(poly_nc)], start = 0.1, dn_cut = 0.0001, to_plot_curve = True, to_plot = False, cuttt = 0.95)
# Out:
# C:\Users\astar\anaconda3\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# (0.04324373357358607,
#     AF bin     Alpha  Cutoff               [[dc1, du1], [pc1, pu1]]  \
#  0     0.2 -0.224987   2.414  [[136870, 3188436], [52780, 1003693]]
#  1     0.3 -0.155118   2.346   [[144903, 3180403], [37964, 721362]]
#  2     0.4 -0.107084   2.295   [[150831, 3174475], [23877, 453920]]
#  3     0.5 -0.074950   2.259   [[155212, 3170094], [23687, 450125]]
#  4     0.6 -0.050574   2.235   [[158541, 3166765], [17563, 333895]]
#  5     0.7 -0.019170   2.204   [[163223, 3162083], [16306, 309930]]
#  6     0.8  0.007104   2.180   [[167293, 3158013], [19546, 371608]]
#  7     0.9  0.028431   2.161   [[170828, 3154478], [18834, 357875]]
#
#                  [[dc2, du2], [pc2, pu2]]  Num Poly in Bin
#  0  [[136989, 3188317], [52824, 1003649]]          1056473
#  1   [[145028, 3180278], [37997, 721329]]           759326
#  2   [[150946, 3174360], [23895, 453902]]           477797
#  3   [[155339, 3169967], [23713, 450099]]           473812
#  4   [[158693, 3166613], [17577, 333881]]           351458
#  5   [[163394, 3161912], [16321, 309915]]           326236
#  6   [[167468, 3157838], [19566, 371588]]           391154
#  7   [[171025, 3154281], [18847, 357862]]           376709  )

# %%
asymptotic_unfold_cutoff(v[v["Position"].isin(fixed_nc)], vv[vv["Position"].isin(poly_nc)], start = 0.1, dn_cut = 0.0001, to_plot_curve = True, to_plot = False, cuttt = 0.6)
# Out:
# (0.02817269267648714,
#     AF bin     Alpha  Cutoff                [[dc1, du1], [pc1, pu1]]  \
#  0     0.2 -0.051953   0.279  [[1289428, 2035878], [422431, 634042]]
#  1     0.3 -0.030256   0.269  [[1305220, 2020086], [303463, 455863]]
#  2     0.4 -0.022406   0.265  [[1311591, 2013715], [190985, 286812]]
#  3     0.5 -0.009377   0.259  [[1321509, 2003797], [189351, 284461]]
#  4     0.6 -0.000394   0.254  [[1329590, 1995716], [140555, 210903]]
#  5     0.7  0.005007   0.252  [[1332855, 1992451], [130377, 195859]]
#  6     0.8  0.014800   0.247  [[1341084, 1984222], [156360, 234794]]
#  7     0.9  0.024498   0.242  [[1349343, 1975963], [150605, 226104]]
#
#                   [[dc2, du2], [pc2, pu2]]  Num Poly in Bin
#  0  [[1290983, 2034323], [422935, 633538]]          1056473
#  1  [[1306788, 2018518], [303813, 455513]]           759326
#  2  [[1313174, 2012132], [191225, 286572]]           477797
#  3  [[1323119, 2002187], [189594, 284218]]           473812
#  4  [[1331214, 1994092], [140737, 210721]]           351458
#  5  [[1334531, 1990775], [130526, 195710]]           326236
#  6  [[1342721, 1982585], [156531, 234623]]           391154
#  7  [[1350932, 1974374], [150801, 225908]]           376709  )

# %%
asymptotic_unfold_cutoff(v[v["Position"].isin(fixed_5p)], vv[vv["Position"].isin(poly_5p)], start = 0.1, dn_cut = 0.0001, to_plot_curve = True, to_plot = False, cuttt = 0.6)
# Out:
# C:\Users\astar\anaconda3\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# (0.07667852644767201,
#     AF bin     Alpha  Cutoff      [[dc1, du1], [pc1, pu1]]  \
#  0     0.2 -0.118311   0.707  [[4599, 7718], [1882, 2824]]
#  1     0.3 -0.064432   0.654  [[4744, 7573], [1233, 1851]]
#  2     0.4  0.001041   0.597   [[4931, 7386], [700, 1053]]
#  3     0.5 -0.030605   0.623   [[4831, 7486], [740, 1114]]
#  4     0.6 -0.015124   0.612    [[4882, 7435], [488, 733]]
#  5     0.7  0.047348   0.549    [[5071, 7246], [436, 655]]
#  6     0.8  0.095958   0.509    [[5217, 7100], [513, 774]]
#  7     0.9  0.040377   0.560    [[5045, 7272], [476, 716]]
#
#         [[dc2, du2], [pc2, pu2]]  Num Poly in Bin
#  0  [[4602, 7715], [1883, 2823]]             4706
#  1  [[4746, 7571], [1235, 1849]]             3084
#  2   [[4933, 7384], [703, 1050]]             1753
#  3   [[4837, 7480], [742, 1112]]             1854
#  4    [[4885, 7432], [489, 732]]             1221
#  5    [[5073, 7244], [437, 654]]             1091
#  6    [[5223, 7094], [515, 772]]             1287
#  7    [[5047, 7270], [477, 715]]             1192  )

# %%
asymptotic_unfold_cutoff(v[v["Position"].isin(fixed_3p)], vv[vv["Position"].isin(poly_3p)], start = 0.1, dn_cut = 0.0001, to_plot_curve = True, to_plot = False, cuttt = 0.6)
# Out:
# C:\Users\astar\anaconda3\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\astar\PosSelect_ForPub\PosSelect_Functions_Old.py:145: RuntimeWarning: invalid value encountered in log
#   return a + d*np.log(x + c)
# (0.09327109622522195,
#     AF bin     Alpha  Cutoff         [[dc1, du1], [pc1, pu1]]  \
#  0     0.2 -0.088085   0.685  [[23816, 38895], [6906, 10367]]
#  1     0.3 -0.002573   0.618   [[25048, 37663], [4866, 7301]]
#  2     0.4  0.007647   0.610   [[25182, 37529], [2996, 4498]]
#  3     0.5  0.022151   0.598   [[25419, 37292], [2926, 4391]]
#  4     0.6  0.068418   0.558   [[26147, 36564], [2047, 3075]]
#  5     0.7  0.035060   0.588   [[25607, 37104], [1912, 2872]]
#  6     0.8  0.118905   0.514   [[27011, 35700], [2236, 3356]]
#  7     0.9  0.071021   0.555   [[26208, 36503], [2117, 3176]]
#
#            [[dc2, du2], [pc2, pu2]]  Num Poly in Bin
#  0  [[23833, 38878], [6912, 10361]]            17273
#  1   [[25061, 37650], [4871, 7296]]            12167
#  2   [[25208, 37503], [2998, 4496]]             7494
#  3   [[25429, 37282], [2928, 4389]]             7317
#  4   [[26162, 36549], [2050, 3072]]             5122
#  5   [[25624, 37087], [1914, 2870]]             4784
#  6   [[27028, 35683], [2239, 3353]]             5592
#  7   [[26225, 36486], [2120, 3173]]             5293  )

# %%
asymptotic_unfold_cutoff(v[v["Position"].isin(fixed_mis)], vv[vv["Position"].isin(poly_mis)], start = 0.1, dn_cut = 0.0001, to_plot_curve = True, to_plot = False, cuttt = 0.6)
# Out:
# C:\Users\astar\anaconda3\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\astar\PosSelect_ForPub\PosSelect_Functions_Old.py:145: RuntimeWarning: invalid value encountered in log
#   return a + d*np.log(x + c)
# (-0.045699676038474885,
#     AF bin     Alpha  Cutoff       [[dc1, du1], [pc1, pu1]]  \
#  0     0.2 -0.908111   2.538  [[5107, 14622], [2450, 3677]]
#  1     0.3 -0.585309   2.159  [[5837, 13892], [1369, 2055]]
#  2     0.4 -0.329298   1.787    [[6592, 13137], [651, 977]]
#  3     0.5 -0.298299   1.752    [[6694, 13035], [522, 784]]
#  4     0.6 -0.115728   1.500    [[7370, 12359], [280, 422]]
#  5     0.7 -0.167466   1.601    [[7158, 12571], [188, 284]]
#  6     0.8 -0.051648   1.398    [[7663, 12066], [174, 263]]
#  7     0.9 -0.196863   1.651    [[7035, 12694], [102, 155]]
#
#          [[dc2, du2], [pc2, pu2]]  Num Poly in Bin
#  0  [[5108, 14621], [2451, 3676]]             6127
#  1  [[5843, 13886], [1370, 2054]]             3424
#  2    [[6594, 13135], [652, 976]]             1628
#  3    [[6696, 13033], [523, 783]]             1306
#  4    [[7372, 12357], [281, 421]]              702
#  5    [[7160, 12569], [189, 283]]              472
#  6    [[7664, 12065], [176, 261]]              437
#  7    [[7037, 12692], [103, 154]]              257  )

# %%
asymptotic_unfold_cutoff(v[v["Position"].isin(fixed_mis + fixed_syn)], vv[vv["Position"].isin(poly_mis + poly_syn)], start = 0.1, dn_cut = 0.0001, to_plot_curve = True, to_plot = False, cuttt = 0.6)
# Out:
# C:\Users\astar\anaconda3\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# (0.03748739885709437,
#     AF bin     Alpha  Cutoff         [[dc1, du1], [pc1, pu1]]  \
#  0     0.2 -0.384086   1.320  [[19926, 41384], [7553, 11334]]
#  1     0.3 -0.265102   1.157   [[21152, 40158], [5157, 7738]]
#  2     0.4 -0.160879   1.030   [[22361, 38949], [3031, 4547]]
#  3     0.5 -0.168218   1.038   [[22271, 39039], [2926, 4390]]
#  4     0.6 -0.043321   0.874   [[23892, 37418], [2131, 3199]]
#  5     0.7 -0.033772   0.862   [[24018, 37292], [1880, 2825]]
#  6     0.8 -0.049330   0.882   [[23815, 37495], [2305, 3460]]
#  7     0.9  0.028476   0.772   [[24937, 36373], [2128, 3197]]
#
#            [[dc2, du2], [pc2, pu2]]  Num Poly in Bin
#  0  [[19934, 41376], [7556, 11331]]            18887
#  1   [[21165, 40145], [5159, 7736]]            12895
#  2   [[22374, 38936], [3032, 4546]]             7578
#  3   [[22282, 39028], [2927, 4389]]             7316
#  4   [[23902, 37408], [2132, 3198]]             5330
#  5   [[24030, 37280], [1882, 2823]]             4705
#  6   [[23823, 37487], [2307, 3458]]             5765
#  7   [[24952, 36358], [2131, 3194]]             5325  )

# %%
asymptotic_unfold_cutoff(v[v["Position"].isin(fixed_syn)], vv[vv["Position"].isin(poly_syn)], start = 0.1, dn_cut = 0.0001, to_plot_curve = True, to_plot = False, cuttt = 0.6)
# Out:
# (-0.15466040553982907,
#     AF bin     Alpha  Cutoff        [[dc1, du1], [pc1, pu1]]  \
#  0     0.2 -0.187163   0.814  [[14945, 26636], [5101, 7659]]
#  1     0.3 -0.195784   0.828  [[14885, 26696], [3788, 5683]]
#  2     0.4 -0.174443   0.800  [[15054, 26527], [2379, 3571]]
#  3     0.5 -0.240070   0.886  [[14534, 27047], [2403, 3607]]
#  4     0.6 -0.144842   0.768  [[15303, 26278], [1851, 2777]]
#  5     0.7 -0.175741   0.802  [[15038, 26543], [1692, 2541]]
#  6     0.8 -0.205778   0.840  [[14807, 26774], [2131, 3197]]
#  7     0.9 -0.123138   0.748  [[15488, 26093], [2026, 3042]]
#
#           [[dc2, du2], [pc2, pu2]]  Num Poly in Bin
#  0  [[14952, 26629], [5104, 7656]]            12760
#  1  [[14888, 26693], [3790, 5681]]             9471
#  2  [[15059, 26522], [2381, 3569]]             5950
#  3  [[14536, 27045], [2404, 3606]]             6010
#  4  [[15316, 26265], [1853, 2775]]             4628
#  5  [[15050, 26531], [1694, 2539]]             4233
#  6  [[14814, 26767], [2133, 3195]]             5328
#  7  [[15493, 26088], [2029, 3039]]             5068  )

# %%
hpo = pd.read_csv("../DPSC_CNCC/HPO_AccelEvol_Input.txt", sep= "\t")
d_HPO = {}

for index, row in hpo.iterrows():
    d_HPO[row["Term"]] = row["Genes"].split(";")

# %%
to_do_vep = to_do_vep[~to_do_vep["Chrom"].isin(["Y"])]
to_do_vep
# Out:
#                Chrom        Pos  1 MusculusReference MajorAllele MinorAllele  \
# Position
# chr4:72665267      4   72665267  .                 A           A           G
# chr4:72666242      4   72666242  .                 T           T           A
# chr4:72666581      4   72666581  .                 T           T           G
# chr4:72666754      4   72666754  .                 T           C           T
# chr4:72667709      4   72667709  .                 C           C           T
# ...              ...        ... ..               ...         ...         ...
# chr4:148957217     4  148957217  .                 T           T           G
# chr4:148957576     4  148957576  .                 C           C           T
# chr4:148958024     4  148958024  .                 G           G           A
# chr4:148958533     4  148958533  .                 G           G           A
# chr4:148958619     4  148958619  .                 A           A           G
#
#                 2  3  4
# Position
# chr4:72665267   .  .  .
# chr4:72666242   .  .  .
# chr4:72666581   .  .  .
# chr4:72666754   .  .  .
# chr4:72667709   .  .  .
# ...            .. .. ..
# chr4:148957217  .  .  .
# chr4:148957576  .  .  .
# chr4:148958024  .  .  .
# chr4:148958533  .  .  .
# chr4:148958619  .  .  .
#
# [277013 rows x 9 columns]

# %%
out = []
c = 0
for index, row in to_do_vep.iterrows():
    c += 1
    if row["MusculusReference"] == row["MajorAllele"]:
        out.append(list(row[["Chrom", "Pos", 1, "MusculusReference", "MinorAllele", 2, 3, 4]]))
    elif row["MusculusReference"] == row["MinorAllele"]:
        out.append(list(row[["Chrom", "Pos", 1, "MusculusReference", "MajorAllele", 2, 3, 4]]))

df = pd.DataFrame(out)
df.to_csv("Mus_VEP/Poly_Mmd_VEP12_chr4_L277013.vcf", sep = "\t", header = False, index = False)

# %%
vv.dropna(subset = ["Effect"])
# Out:
# nan

# %%
v_vep_rest = v_vep[v_vep["Chrom"].isin(["X", "Y"])]
v_vep_rest_X = v_vep_rest[(~v_vep_rest["Pos"].astype(int).isin(bleh[1])) & (v_vep_rest["Chrom"].isin(["X"]))]
v_vep_rest_Y = v_vep[v_vep["Chrom"].isin(["Y"])]
v_vep_rest_X.to_csv("Mus_VEP/Fixed_Mmd_VEP14.vcf", header = False, index = False)

# %%
~v_vep_rest["Pos"].isin(bleh[1])
# Out:
# 18069437    True
# 18069438    True
# 18069439    True
# 18069446    True
# 18069448    True
#             ...
# 19302011    True
# 19302013    True
# 19302015    True
# 19302017    True
# 19302018    True
# Name: Pos, Length: 506151, dtype: bool

# %%
vep = pd.read_csv("Mus_VEP/FE87HaVJlO1mzH0A.txt", sep = '\t')
vep
# Out:
#        #Uploaded_variation               Location Allele  \
# 0                        .  4:130292696-130292696      T
# 1                        .  4:130292696-130292696      T
# 2                        .  4:130292710-130292710      C
# 3                        .  4:130292710-130292710      C
# 4                        .  4:130292812-130292812      A
# ...                    ...                    ...    ...
# 321312                   .  4:148958533-148958533      A
# 321313                   .  4:148958533-148958533      A
# 321314                   .  4:148958619-148958619      G
# 321315                   .  4:148958619-148958619      G
# 321316                   .  4:148958619-148958619      G
#
#                                          Consequence    IMPACT  SYMBOL  \
# 0                              upstream_gene_variant  MODIFIER  Nkain1
# 1                              upstream_gene_variant  MODIFIER  Nkain1
# 2                              upstream_gene_variant  MODIFIER  Nkain1
# 3                              upstream_gene_variant  MODIFIER  Nkain1
# 4                              upstream_gene_variant  MODIFIER  Nkain1
# ...                                              ...       ...     ...
# 321312                                intron_variant  MODIFIER   Casz1
# 321313  intron_variant,non_coding_transcript_variant  MODIFIER       -
# 321314                                intron_variant  MODIFIER   Casz1
# 321315                                intron_variant  MODIFIER   Casz1
# 321316  intron_variant,non_coding_transcript_variant  MODIFIER       -
#
#                       Gene Feature_type                Feature  \
# 0       ENSMUSG00000078532   Transcript   ENSMUST00000105993.4
# 1       ENSMUSG00000078532   Transcript   ENSMUST00000180884.8
# 2       ENSMUSG00000078532   Transcript   ENSMUST00000105993.4
# 3       ENSMUSG00000078532   Transcript   ENSMUST00000180884.8
# 4       ENSMUSG00000078532   Transcript   ENSMUST00000105993.4
# ...                    ...          ...                    ...
# 321312  ENSMUSG00000028977   Transcript   ENSMUST00000122222.8
# 321313  ENSMUSG00000138871   Transcript   ENSMUST00000350078.1
# 321314  ENSMUSG00000028977   Transcript  ENSMUST00000094464.10
# 321315  ENSMUSG00000028977   Transcript   ENSMUST00000122222.8
# 321316  ENSMUSG00000138871   Transcript   ENSMUST00000350078.1
#
#                         BIOTYPE  ... APPRIS SIFT CLIN_SIG SOMATIC PHENO  \
# 0                protein_coding  ...     P1    -        -       -     -
# 1       nonsense_mediated_decay  ...      -    -        -       -     -
# 2                protein_coding  ...     P1    -        -       -     -
# 3       nonsense_mediated_decay  ...      -    -        -       -     -
# 4                protein_coding  ...     P1    -        -       -     -
# ...                         ...  ...    ...  ...      ...     ...   ...
# 321312           protein_coding  ...     P1    -        -       -     -
# 321313                   lncRNA  ...      -    -        -       -     -
# 321314           protein_coding  ...      -    -        -       -     -
# 321315           protein_coding  ...     P1    -        -       -     -
# 321316                   lncRNA  ...      -    -        -       -     -
#
#        MOTIF_NAME MOTIF_POS HIGH_INF_POS MOTIF_SCORE_CHANGE  \
# 0               -         -            -                  -
# 1               -         -            -                  -
# 2               -         -            -                  -
# 3               -         -            -                  -
# 4               -         -            -                  -
# ...           ...       ...          ...                ...
# 321312          -         -            -                  -
# 321313          -         -            -                  -
# 321314          -         -            -                  -
# 321315          -         -            -                  -
# 321316          -         -            -                  -
#
#        TRANSCRIPTION_FACTORS
# 0                          -
# 1                          -
# 2                          -
# 3                          -
# 4                          -
# ...                      ...
# 321312                     -
# 321313                     -
# 321314                     -
# 321315                     -
# 321316                     -
#
# [321317 rows x 41 columns]

# %%
print(len(np.unique(vep["Location"])))
# Out:
# 69253

# %%
554027/2
# Out:
# 277013.5

# %%
x = pd.read_csv("Mus_VEP/Poly_Mmd_VEP12_chr4.vcf", sep = "\t", header = None)
x = x.sort_values(1)
x.head(277013).to_csv("Mus_VEP/Poly_Mmd_VEP12_chr4_L277013.vcf", header = False, index = False, sep = "\t")
x
# Out:
#         0          1  2  3  4  5  6  7
# 0       4    3139093  .  A  G  .  .  .
# 1       4    3166969  .  G  C  .  .  .
# 2       4    3167846  .  T  A  .  .  .
# 3       4    3169016  .  C  A  .  .  .
# 4       4    3169487  .  A  C  .  .  .
# ...    ..        ... .. .. .. .. .. ..
# 554022  4  148957217  .  T  G  .  .  .
# 554023  4  148957576  .  C  T  .  .  .
# 554024  4  148958024  .  G  A  .  .  .
# 554025  4  148958533  .  G  A  .  .  .
# 554026  4  148958619  .  A  G  .  .  .
#
# [554027 rows x 8 columns]

# %%
x = pd.read_csv("Mus_VEP/Fixed_Mmd_VEP14.vcf", header = None)
x.to_csv("Mus_VEP/Fixed_Mmd_VEP14.vcf", index = False, header = False, sep = "\t")

# %%
x = pd.read_csv("Mus_VEP/Fixed_Mmd_VEP4_chr14.vcf", sep = "\t", header = None)
x = x.sort_values(1)
x.tail(272936-135000).to_csv("Mus_VEP/Fixed_Mmd_VEP4_chr14_L137936.vcf", header = False, index = False, sep = "\t")

# %%
x = pd.read_csv("Mus_VEP/Fixed_Mmd_VEP9_chr4.vcf", sep = "\t", header = None)
x = x.sort_values(1)
x.tail(228342).to_csv("Mus_VEP/Fixed_Mmd_VEP9_chr4_L228342.vcf", header = False, index = False, sep = "\t")
x
# Out:
#         0          1  2  3  4  5  6  7
# 0       4    3103995  .  G  A  .  .  .
# 1       4    3134336  .  T  C  .  .  .
# 2       4    3151963  .  T  C  .  .  .
# 3       4    3221731  .  A  G  .  .  .
# 4       4    3230921  .  T  C  .  .  .
# ...    ..        ... .. .. .. .. .. ..
# 456679  4  149933704  .  T  C  .  .  .
# 456680  4  149933966  .  C  T  .  .  .
# 456681  4  149934011  .  G  C  .  .  .
# 456682  4  149934728  .  C  T  .  .  .
# 456683  4  149934827  .  A  T  .  .  .
#
# [456684 rows x 8 columns]

# %%
vep[vep["Consequence"].isin(["missense_variant"])].head(500)
# Out:
#        #Uploaded_variation             Location Allele       Consequence  \
# 4011                     .    1:4089333-4089333      T  missense_variant
# 4517                     .    1:4298829-4298829      G  missense_variant
# 4534                     .    1:4301292-4301292      G  missense_variant
# 4858                     .    1:4415076-4415076      T  missense_variant
# 4861                     .    1:4415085-4415085      T  missense_variant
# ...                    ...                  ...    ...               ...
# 435505                   .  1:40813265-40813265      T  missense_variant
# 435741                   .  1:40825356-40825356      T  missense_variant
# 435765                   .  1:40826716-40826716      A  missense_variant
# 436195                   .  1:40894108-40894108      A  missense_variant
# 485351                   .  1:43072445-43072445      G  missense_variant
#
#           IMPACT   SYMBOL                Gene Feature_type  \
# 4011    MODERATE      Rp1  ENSMUSG00000025900   Transcript
# 4517    MODERATE      Rp1  ENSMUSG00000025900   Transcript
# 4534    MODERATE      Rp1  ENSMUSG00000025900   Transcript
# 4858    MODERATE      Rp1  ENSMUSG00000025900   Transcript
# 4861    MODERATE      Rp1  ENSMUSG00000025900   Transcript
# ...          ...      ...                 ...          ...
# 435505  MODERATE    Mfsd9  ENSMUSG00000041945   Transcript
# 435741  MODERATE    Mfsd9  ENSMUSG00000041945   Transcript
# 435765  MODERATE    Mfsd9  ENSMUSG00000041945   Transcript
# 436195  MODERATE  Tmem182  ENSMUSG00000079588   Transcript
# 485351  MODERATE    Gpr45  ENSMUSG00000041907   Transcript
#
#                      Feature         BIOTYPE  ... APPRIS               SIFT  \
# 4011    ENSMUST00000208660.2  protein_coding  ...     P1    tolerated(0.52)
# 4517    ENSMUST00000208660.2  protein_coding  ...     P1       tolerated(1)
# 4534    ENSMUST00000208660.2  protein_coding  ...     P1  deleterious(0.03)
# 4858    ENSMUST00000027032.6  protein_coding  ...      -       tolerated(1)
# 4861    ENSMUST00000027032.6  protein_coding  ...      -    tolerated(0.64)
# ...                      ...             ...  ...    ...                ...
# 435505  ENSMUST00000039672.6  protein_coding  ...     P1    tolerated(0.07)
# 435741  ENSMUST00000039672.6  protein_coding  ...     P1       tolerated(1)
# 435765  ENSMUST00000039672.6  protein_coding  ...     P1    tolerated(0.06)
# 436195  ENSMUST00000114765.4  protein_coding  ...     P1    tolerated(0.83)
# 485351  ENSMUST00000114761.2  protein_coding  ...     P1    tolerated(0.98)
#
#        CLIN_SIG SOMATIC PHENO MOTIF_NAME MOTIF_POS HIGH_INF_POS  \
# 4011          -       -     -          -         -            -
# 4517          -       -     -          -         -            -
# 4534          -       -     -          -         -            -
# 4858          -       -     -          -         -            -
# 4861          -       -     -          -         -            -
# ...         ...     ...   ...        ...       ...          ...
# 435505        -       -     -          -         -            -
# 435741        -       -     -          -         -            -
# 435765        -       -     -          -         -            -
# 436195        -       -     -          -         -            -
# 485351        -       -     -          -         -            -
#
#        MOTIF_SCORE_CHANGE TRANSCRIPTION_FACTORS
# 4011                    -                     -
# 4517                    -                     -
# 4534                    -                     -
# 4858                    -                     -
# 4861                    -                     -
# ...                   ...                   ...
# 435505                  -                     -
# 435741                  -                     -
# 435765                  -                     -
# 436195                  -                     -
# 485351                  -                     -
#
# [500 rows x 41 columns]

# %%
ivep = pd.read_csv("Mus_VEP/Fixed_Mmd_VEP9_chr4_F228342.vcf", sep = '\t', header = None)
#ivep[ivep[0].isin([4])].to_csv("Mus_VEP/Poly_Mmd_VEP12_chr4.vcf", header = False, index = False, sep = "\t")
ivep
# Out:
#         0         1  2  3  4  5  6  7
# 0       4   3103995  .  G  A  .  .  .
# 1       4   3134336  .  T  C  .  .  .
# 2       4   3151963  .  T  C  .  .  .
# 3       4   3221731  .  A  G  .  .  .
# 4       4   3230921  .  T  C  .  .  .
# ...    ..       ... .. .. .. .. .. ..
# 228337  4  73640816  .  T  A  .  .  .
# 228338  4  73640832  .  A  C  .  .  .
# 228339  4  73640967  .  A  T  .  .  .
# 228340  4  73641000  .  T  G  .  .  .
# 228341  4  73641124  .  A  G  .  .  .
#
# [228342 rows x 8 columns]

# %%
ivep[1].astype(float)
# Out:
# 0         16637593.0
# 1         16637613.0
# 2         16637721.0
# 3         16637754.0
# 4         16637790.0
#              ...
# 599995    97443326.0
# 599996    97444002.0
# 599997    97445918.0
# 599998    97447130.0
# 599999    97447285.0
# Name: 1, Length: 600000, dtype: float64

# %%
from collections import Counter
len(np.unique(ivep[1]))
# Out:
# 599269

# %%
vep = pd.read_csv("Mus_VEP/Fixed_Mmd_VEP1_Output.txt", sep = "\t")

# %%
from collections import Counter
mis = []
three = []
five = []
syn = []
nc = []
for index, row in vep.iterrows():
    if "missense" in row["Consequence"] and "NMD" not in row["Consequence"]:
        mis.append(row["Location"].split("-")[0])
    elif "3_prime_UTR" in row["Consequence"] and "NMD" not in row["Consequence"]:
        three.append(row["Location"].split("-")[0])
    elif "5_prime_UTR" in row["Consequence"] and "NMD" not in row["Consequence"]:
        five.append(row["Location"].split("-")[0])
    elif "synonymous" in row["Consequence"] and "NMD" not in row["Consequence"]:
        syn.append(row["Location"].split("-")[0])
        nc.append(row["Location"].split("-")[0])
    else:
        nc.append(row["Location"].split("-")[0])
mis = list(set(mis))
three = np.setdiff1d(list(set(three)), mis)
five = np.setdiff1d(np.setdiff1d(list(set(five)), mis), three)
syn = np.setdiff1d(np.setdiff1d(np.setdiff1d(list(set(syn)), mis), three), five)
nc = np.setdiff1d(np.setdiff1d(np.setdiff1d(list(set(nc)), mis), three), five)

print(len(nc) + len(mis) + len(three) + len(five))
# Out:
# KeyboardInterrupt

# %%
veps = pd.DataFrame(["chr" + x for x in mis + three + five + syn + nc])
veps["Effect"] = list(np.repeat("Mis", len(mis))) + list(np.repeat("3P", len(three))) + list(np.repeat("5P", len(five))) + list(np.repeat("Syn", len(syn))) + list(np.repeat("NC", len(nc)))
veps.columns = ["Position", "Effect"]
veps.to_csv("Fixed_Mmd_AllVEPs.txt", sep = "\t", index = False)

# %%
import os
mis_all = []
three_all = []
five_all = []
syn_all = []
nc_all = []
for file in os.listdir("Mus_VEP"):
    if "Output" in file and "Fixed" in file:
        print(file)
        vep = pd.read_csv("Mus_VEP/" + file, sep = "\t")
        mis = []
        three = []
        five = []
        syn = []
        nc = []
        for index, row in vep.iterrows():
            if "missense" in row["Consequence"] and "NMD" not in row["Consequence"]:
                mis.append(row["Location"].split("-")[0])
            elif "3_prime_UTR" in row["Consequence"] and "NMD" not in row["Consequence"]:
                three.append(row["Location"].split("-")[0])
            elif "5_prime_UTR" in row["Consequence"] and "NMD" not in row["Consequence"]:
                five.append(row["Location"].split("-")[0])
            elif "synonymous" in row["Consequence"] and "NMD" not in row["Consequence"]:
                syn.append(row["Location"].split("-")[0])
                nc.append(row["Location"].split("-")[0])
            else:
                nc.append(row["Location"].split("-")[0])
        mis = list(set(mis))
        three = list(np.setdiff1d(list(set(three)), mis))
        five = list(np.setdiff1d(np.setdiff1d(list(set(five)), mis), three))
        syn = list(np.setdiff1d(np.setdiff1d(np.setdiff1d(list(set(syn)), mis), three), five))
        nc = list(np.setdiff1d(np.setdiff1d(np.setdiff1d(list(set(nc)), mis), three), five))

        print(len(nc) + len(mis) + len(three) + len(five))
        
        mis_all = mis_all + mis
        three_all = three_all + three
        five_all = five_all + five
        syn_all = syn_all + syn
        nc_all = nc_all + nc
        
veps = pd.DataFrame(["chr" + x for x in mis_all + three_all + five_all + syn_all + nc_all])
veps["Effect"] = list(np.repeat("Mis", len(mis_all))) + list(np.repeat("3P", len(three_all))) + list(np.repeat("5P", len(five_all))) + list(np.repeat("Syn", len(syn_all))) + list(np.repeat("NC", len(nc_all)))
veps.columns = ["Position", "Effect"]
veps.to_csv("Fixed_Mmd_AllVEPs.txt", sep = "\t", index = False)
# Out:
# Fixed_Mmd_VEP10_Output.txt
# C:\Users\astar\AppData\Local\Temp\ipykernel_6552\1272783498.py:10: DtypeWarning: Columns (23) have mixed types. Specify dtype option on import or set low_memory=False.
#   vep = pd.read_csv("Mus_VEP/" + file, sep = "\t")
# 600000
# Fixed_Mmd_VEP11_Output.txt
# C:\Users\astar\AppData\Local\Temp\ipykernel_6552\1272783498.py:10: DtypeWarning: Columns (23) have mixed types. Specify dtype option on import or set low_memory=False.
#   vep = pd.read_csv("Mus_VEP/" + file, sep = "\t")
# 600000
# Fixed_Mmd_VEP12_Output.txt
# C:\Users\astar\AppData\Local\Temp\ipykernel_6552\1272783498.py:10: DtypeWarning: Columns (23) have mixed types. Specify dtype option on import or set low_memory=False.
#   vep = pd.read_csv("Mus_VEP/" + file, sep = "\t")
# 600000
# Fixed_Mmd_VEP13_Output.txt
# C:\Users\astar\AppData\Local\Temp\ipykernel_6552\1272783498.py:10: DtypeWarning: Columns (23) have mixed types. Specify dtype option on import or set low_memory=False.
#   vep = pd.read_csv("Mus_VEP/" + file, sep = "\t")
# 600000
# Fixed_Mmd_VEP14_Output.txt
# 168569
# Fixed_Mmd_VEP1_Output.txt
# 600000
# Fixed_Mmd_VEP2_Output.txt
# C:\Users\astar\AppData\Local\Temp\ipykernel_6552\1272783498.py:10: DtypeWarning: Columns (23,30) have mixed types. Specify dtype option on import or set low_memory=False.
#   vep = pd.read_csv("Mus_VEP/" + file, sep = "\t")
# 600000
# Fixed_Mmd_VEP3_Output.txt
# 600000
# Fixed_Mmd_VEP4_chr13_Output.txt
# 327064
# Fixed_Mmd_VEP4_chr14_F135000_Output.txt
# 135000
# Fixed_Mmd_VEP4_chr14_L137936_Output.txt
# C:\Users\astar\AppData\Local\Temp\ipykernel_6552\1272783498.py:10: DtypeWarning: Columns (23) have mixed types. Specify dtype option on import or set low_memory=False.
#   vep = pd.read_csv("Mus_VEP/" + file, sep = "\t")
# 137936
# Fixed_Mmd_VEP5_Output.txt
# C:\Users\astar\AppData\Local\Temp\ipykernel_6552\1272783498.py:10: DtypeWarning: Columns (23) have mixed types. Specify dtype option on import or set low_memory=False.
#   vep = pd.read_csv("Mus_VEP/" + file, sep = "\t")
# 600000
# Fixed_Mmd_VEP6_Output.txt
# C:\Users\astar\AppData\Local\Temp\ipykernel_6552\1272783498.py:10: DtypeWarning: Columns (23) have mixed types. Specify dtype option on import or set low_memory=False.
#   vep = pd.read_csv("Mus_VEP/" + file, sep = "\t")
# 600000
# Fixed_Mmd_VEP7_Output.txt
# C:\Users\astar\AppData\Local\Temp\ipykernel_6552\1272783498.py:10: DtypeWarning: Columns (23) have mixed types. Specify dtype option on import or set low_memory=False.
#   vep = pd.read_csv("Mus_VEP/" + file, sep = "\t")
# 600000
# Fixed_Mmd_VEP8_Output.txt
# 600000
# Fixed_Mmd_VEP9_chr3_Output.txt
# 143316
# Fixed_Mmd_VEP9_chr4_F228342_Output.txt
# 228342
# Fixed_Mmd_VEP9_chr4_L228342_Output.txt
# 228342

# %%
import os
mis_all = []
three_all = []
five_all = []
syn_all = []
nc_all = []
for file in os.listdir("Mus_VEP"):
    
    if "Output" in file and "Poly" in file:
        print(file)
        vep = pd.read_csv("Mus_VEP/" + file, sep = "\t")
        mis = []
        three = []
        five = []
        syn = []
        nc = []
        for index, row in vep.iterrows():
            if "missense" in row["Consequence"] and "NMD" not in row["Consequence"]:
                mis.append(row["Location"].split("-")[0])
            elif "3_prime_UTR" in row["Consequence"] and "NMD" not in row["Consequence"]:
                three.append(row["Location"].split("-")[0])
            elif "5_prime_UTR" in row["Consequence"] and "NMD" not in row["Consequence"]:
                five.append(row["Location"].split("-")[0])
            elif "synonymous" in row["Consequence"] and "NMD" not in row["Consequence"]:
                syn.append(row["Location"].split("-")[0])
                nc.append(row["Location"].split("-")[0])
            else:
                nc.append(row["Location"].split("-")[0])
        mis = list(set(mis))
        three = list(np.setdiff1d(list(set(three)), mis))
        five = list(np.setdiff1d(np.setdiff1d(list(set(five)), mis), three))
        syn = list(np.setdiff1d(np.setdiff1d(np.setdiff1d(list(set(syn)), mis), three), five))
        nc = list(np.setdiff1d(np.setdiff1d(np.setdiff1d(list(set(nc)), mis), three), five))

        print(len(nc) + len(mis) + len(three) + len(five))
        
        mis_all = mis_all + mis
        three_all = three_all + three
        five_all = five_all + five
        syn_all = syn_all + syn
        nc_all = nc_all + nc
        
veps = pd.DataFrame(["chr" + x for x in mis_all + three_all + five_all + syn_all + nc_all])
veps["Effect"] = list(np.repeat("Mis", len(mis_all))) + list(np.repeat("3P", len(three_all))) + list(np.repeat("5P", len(five_all))) + list(np.repeat("Syn", len(syn_all))) + list(np.repeat("NC", len(nc_all)))
veps.columns = ["Position", "Effect"]
veps.to_csv("Poly_Mmd_AllVEPs.txt", sep = "\t", index = False)
# Out:
# Poly_Mmd_VEP10_Output.txt
# C:\Users\astar\AppData\Local\Temp\ipykernel_6552\3891694948.py:11: DtypeWarning: Columns (23) have mixed types. Specify dtype option on import or set low_memory=False.
#   vep = pd.read_csv("Mus_VEP/" + file, sep = "\t")
# 596692
# Poly_Mmd_VEP11_Output.txt
# C:\Users\astar\AppData\Local\Temp\ipykernel_6552\3891694948.py:11: DtypeWarning: Columns (23) have mixed types. Specify dtype option on import or set low_memory=False.
#   vep = pd.read_csv("Mus_VEP/" + file, sep = "\t")
# 596564
# Poly_Mmd_VEP12_chr3_Output.txt
# 42683
# Poly_Mmd_VEP12_chr4_F277014_Output.txt
# 277014
# Poly_Mmd_VEP12_chr4_L277013_F138507_Output.txt
# 138507
# Poly_Mmd_VEP12_chr4_L277013_L138506_F69253_Output.txt
# 69253
# Poly_Mmd_VEP12_chr4_L277013_L138506_L69253_Output.txt
# 69253
# Poly_Mmd_VEP13_Output.txt
# C:\Users\astar\AppData\Local\Temp\ipykernel_6552\3891694948.py:11: DtypeWarning: Columns (23) have mixed types. Specify dtype option on import or set low_memory=False.
#   vep = pd.read_csv("Mus_VEP/" + file, sep = "\t")
# 596684
# Poly_Mmd_VEP14_Output.txt
# C:\Users\astar\AppData\Local\Temp\ipykernel_6552\3891694948.py:11: DtypeWarning: Columns (23) have mixed types. Specify dtype option on import or set low_memory=False.
#   vep = pd.read_csv("Mus_VEP/" + file, sep = "\t")
# 596721
# Poly_Mmd_VEP15_Output.txt
# 597051
# Poly_Mmd_VEP16_Output.txt
# 596738
# Poly_Mmd_VEP17_Output.txt
# 596776
# Poly_Mmd_VEP18_Output.txt
# 59667
# Poly_Mmd_VEP1_Output.txt
# C:\Users\astar\AppData\Local\Temp\ipykernel_6552\3891694948.py:11: DtypeWarning: Columns (23) have mixed types. Specify dtype option on import or set low_memory=False.
#   vep = pd.read_csv("Mus_VEP/" + file, sep = "\t")
# 596421
# Poly_Mmd_VEP2_Output.txt
# C:\Users\astar\AppData\Local\Temp\ipykernel_6552\3891694948.py:11: DtypeWarning: Columns (23,30) have mixed types. Specify dtype option on import or set low_memory=False.
#   vep = pd.read_csv("Mus_VEP/" + file, sep = "\t")
# 596840
# Poly_Mmd_VEP3_Output.txt
# C:\Users\astar\AppData\Local\Temp\ipykernel_6552\3891694948.py:11: DtypeWarning: Columns (23) have mixed types. Specify dtype option on import or set low_memory=False.
#   vep = pd.read_csv("Mus_VEP/" + file, sep = "\t")
# 596838
# Poly_Mmd_VEP4_Output.txt
# 596789
# Poly_Mmd_VEP5_chr12-13_Output.txt
# C:\Users\astar\AppData\Local\Temp\ipykernel_6552\3891694948.py:11: DtypeWarning: Columns (23) have mixed types. Specify dtype option on import or set low_memory=False.
#   vep = pd.read_csv("Mus_VEP/" + file, sep = "\t")
# 475789
# Poly_Mmd_VEP5_chr14_F60526_Output.txt
# 60526
# Poly_Mmd_VEP5_chr14_L60527_Output.txt
# C:\Users\astar\AppData\Local\Temp\ipykernel_6552\3891694948.py:11: DtypeWarning: Columns (23,30) have mixed types. Specify dtype option on import or set low_memory=False.
#   vep = pd.read_csv("Mus_VEP/" + file, sep = "\t")
# 60527
# Poly_Mmd_VEP6_Output.txt
# C:\Users\astar\AppData\Local\Temp\ipykernel_6552\3891694948.py:11: DtypeWarning: Columns (23) have mixed types. Specify dtype option on import or set low_memory=False.
#   vep = pd.read_csv("Mus_VEP/" + file, sep = "\t")
# 596412
# Poly_Mmd_VEP7_Output.txt
# C:\Users\astar\AppData\Local\Temp\ipykernel_6552\3891694948.py:11: DtypeWarning: Columns (23) have mixed types. Specify dtype option on import or set low_memory=False.
#   vep = pd.read_csv("Mus_VEP/" + file, sep = "\t")
# 596574
# Poly_Mmd_VEP8_Output.txt
# 596667
# Poly_Mmd_VEP9_Output.txt
# C:\Users\astar\AppData\Local\Temp\ipykernel_6552\3891694948.py:11: DtypeWarning: Columns (23) have mixed types. Specify dtype option on import or set low_memory=False.
#   vep = pd.read_csv("Mus_VEP/" + file, sep = "\t")
# 596756

# %%
df = pd.read_csv("Mus_VEP/Fixed_Mmd_VEP13.vcf", sep = "\t", header = None)
df
# Out:
#         0          1  2  3  4  5  6  7
# 0       1    3073571  .  T  C  .  .  .
# 1       1    3074108  .  C  T  .  .  .
# 2       1    3074212  .  T  C  .  .  .
# 3       1    3074648  .  T  G  .  .  .
# 4       1    3075151  .  G  A  .  .  .
# ...    ..        ... .. .. .. .. .. ..
# 599995  1  191270821  .  A  T  .  .  .
# 599996  1  191270909  .  C  A  .  .  .
# 599997  1  191271102  .  C  T  .  .  .
# 599998  1  191271129  .  C  T  .  .  .
# 599999  1  191271654  .  G  T  .  .  .
#
# [600000 rows x 8 columns]

# %%
vv_vep = vv[["Position", "MusculusReference", "MajorAllele", "MinorAllele"]]
vv_vep["Chrom"] = [x.split(":")[0].replace("chr", "") for x in vv["Position"]]
vv_vep["Pos"] = [x.split(":")[1] for x in vv["Position"]]

vv_vep[1] = np.repeat(".", vv_vep.shape[0])
vv_vep[2] = np.repeat(".", vv_vep.shape[0])
vv_vep[3] = np.repeat(".", vv_vep.shape[0])
vv_vep[4] = np.repeat(".", vv_vep.shape[0])
vv_vep = vv_vep[["Chrom", "Pos", 1, "MusculusReference", "MajorAllele", "MinorAllele", 2, 3, 4]]
vv_vep
# Out:
# C:\Users\astar\AppData\Local\Temp\ipykernel_20172\2374250369.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vv_vep["Chrom"] = [x.split(":")[0].replace("chr", "") for x in vv["Position"]]
# C:\Users\astar\AppData\Local\Temp\ipykernel_20172\2374250369.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vv_vep["Pos"] = [x.split(":")[1] for x in vv["Position"]]
# C:\Users\astar\AppData\Local\Temp\ipykernel_20172\2374250369.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vv_vep[1] = np.repeat(".", vv_vep.shape[0])
# C:\Users\astar\AppData\Local\Temp\ipykernel_20172\2374250369.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vv_vep[2] = np.repeat(".", vv_vep.shape[0])
# C:\Users\astar\AppData\Local\Temp\ipykernel_20172\2374250369.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vv_vep[3] = np.repeat(".", vv_vep.shape[0])
# C:\Users\astar\AppData\Local\Temp\ipykernel_20172\2374250369.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vv_vep[4] = np.repeat(".", vv_vep.shape[0])
#          Chrom       Pos  1 MusculusReference MajorAllele MinorAllele  2  3  4
# 0            1   3073637  .                 G           G           A  .  .  .
# 1            1   3073672  .                 C           C           T  .  .  .
# 2            1   3073687  .                 G           G           A  .  .  .
# 3            1   3074547  .                 T           T           G  .  .  .
# 4            1   3074676  .                 G           G           A  .  .  .
# ...        ...       ... ..               ...         ...         ... .. .. ..
# 10455759     Y  22712697  .                 A           A           G  .  .  .
# 10455760     Y  43884170  .                 C           C           T  .  .  .
# 10455761     Y  43884178  .                 C           C           T  .  .  .
# 10455762     Y  43884950  .                 G           A           G  .  .  .
# 10455763     Y  80054654  .                 G           G           A  .  .  .
#
# [10260057 rows x 9 columns]

# %%
bleh = pd.read_csv("Mus_VEP/Poly_Mmd_VEP17.vcf", sep = "\t", header = None)
bleh
# Out:
# C:\Users\astar\AppData\Local\Temp\ipykernel_20172\3159978483.py:1: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   bleh = pd.read_csv("Mus_VEP/Poly_Mmd_VEP17.vcf", sep = "\t", header = None)
#         0          1  2  3  4  5  6  7
# 0       9   18088363  .  G  C  .  .  .
# 1       9   18088398  .  C  T  .  .  .
# 2       9   18088454  .  T  A  .  .  .
# 3       9   18088659  .  T  C  .  .  .
# 4       9   18088810  .  A  G  .  .  .
# ...    ..        ... .. .. .. .. .. ..
# 596771  X  130503333  .  C  T  .  .  .
# 596772  X  130503759  .  A  G  .  .  .
# 596773  X  130503905  .  C  T  .  .  .
# 596774  X  130503935  .  T  C  .  .  .
# 596775  X  130504825  .  G  C  .  .  .
#
# [596776 rows x 8 columns]

# %%
vv_vep
# Out:
#          Chrom       Pos  1 MusculusReference MajorAllele MinorAllele  2  3  4
# 0            1   3073637  .                 G           G           A  .  .  .
# 1            1   3073672  .                 C           C           T  .  .  .
# 2            1   3073687  .                 G           G           A  .  .  .
# 3            1   3074547  .                 T           T           G  .  .  .
# 4            1   3074676  .                 G           G           A  .  .  .
# ...        ...       ... ..               ...         ...         ... .. .. ..
# 10455759     Y  22712697  .                 A           A           G  .  .  .
# 10455760     Y  43884170  .                 C           C           T  .  .  .
# 10455761     Y  43884178  .                 C           C           T  .  .  .
# 10455762     Y  43884950  .                 G           A           G  .  .  .
# 10455763     Y  80054654  .                 G           G           A  .  .  .
#
# [10260057 rows x 9 columns]

# %%
vv_vep_failed["Position"] = "chr" + vv_vep_failed["Chrom"].astype(str) + ":" + vv_vep_failed["Pos"].astype(str)
vv[vv["Position"].isin(vv_vep_failed["Position"])]
# Out:
# C:\Users\astar\AppData\Local\Temp\ipykernel_20172\3660862080.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vv_vep_failed["Position"] = "chr" + vv_vep_failed["Chrom"].astype(str) + ":" + vv_vep_failed["Pos"].astype(str)
#                 Position MajorAllele MinorAllele  MAFMaxAcrossAncestry  \
# 63          chr1:3097877           C           G                 0.120
# 358         chr1:3150604           G           T                 0.167
# 802         chr1:3266150           C           T                 0.278
# 954         chr1:3356292           G           T                 0.444
# 1183        chr1:3403602           C           G                 0.167
# ...                  ...         ...         ...                   ...
# 10454926  chrX:168054793           G           T                 0.111
# 10454950  chrX:168098636           C           T                 0.148
# 10455415  chrX:168473711           C           T                 0.111
# 10455442  chrX:168497326           C           G                 0.148
# 10455641  chrX:168676475           C           T                 0.185
#
#          DerivedAllele  UnfoldedMAF MusculusReference Spretus Caroli Pahari  \
# 63                 Amb          NaN                 T       C      T      C
# 358                Amb          NaN                 A       G      A      A
# 802                Amb          NaN                 G       C      G      G
# 954                Amb          NaN                 C       G      C      C
# 1183               Amb          NaN                 T       C      T      T
# ...                ...          ...               ...     ...    ...    ...
# 10454926           Amb          NaN                 A       G      A      A
# 10454950           Amb          NaN                 A       C      A      A
# 10455415           Amb          NaN                 A       C      A      A
# 10455442           Amb          NaN                 A       C      A      A
# 10455641           Amb          NaN                 A       C      A      A
#
#          DerivedFromSubspecies  PhyloP447 NearestGene  NearestDist  SpecSup447
# 63                           C     -0.604        Xkr4       643049        15.0
# 358                        Amb      0.166        Xkr4       590322         3.0
# 802                          C      0.671        Xkr4       474776       299.0
# 954                          T      0.208        Xkr4       384634         3.0
# 1183                       Amb      0.140        Xkr4       337324       384.0
# ...                        ...        ...         ...          ...         ...
# 10454926                     A     -0.014        Hccs        47330       418.0
# 10454950                     A     -2.103        Hccs         3487       443.0
# 10455415                    TP      1.485        Mid1         4495       413.0
# 10455442                   Amb      0.462        Mid1        28110         5.0
# 10455641                     A      0.166        Mid1        12853         3.0
#
# [56267 rows x 15 columns]

# %%
vv_vep_failed = vv_vep[(vv_vep["MusculusReference"] != vv_vep["MajorAllele"]) & (vv_vep["MusculusReference"] != vv_vep["MinorAllele"])]

# %%
vv_vep_n = vv_vep[(~vv_vep["Pos"].astype(int).isin(bleh[1])) & (vv_vep["Chrom"].isin(["X"]))]

out = []
c = 0
for index, row in vv_vep_n.iterrows():
    c += 1
    if row["MusculusReference"] == row["MajorAllele"]:
        out.append(list(row[["Chrom", "Pos", 1, "MusculusReference", "MinorAllele", 2, 3, 4]]))
    elif row["MusculusReference"] == row["MinorAllele"]:
        out.append(list(row[["Chrom", "Pos", 1, "MusculusReference", "MajorAllele", 2, 3, 4]]))

df = pd.DataFrame(out)
df.to_csv("Mus_VEP/Poly_Mmd_VEP18.vcf", sep = "\t", header = False, index = False)

# %%
vv_vep = vv[["Position", "MusculusReference", "MajorAllele", "MinorAllele"]]
vv_vep["Chrom"] = [x.split(":")[0].replace("chr", "") for x in vv["Position"]]
vv_vep["Pos"] = [x.split(":")[1] for x in vv["Position"]]

vv_vep[1] = np.repeat(".", vv_vep.shape[0])
vv_vep[2] = np.repeat(".", vv_vep.shape[0])
vv_vep[3] = np.repeat(".", vv_vep.shape[0])
vv_vep[4] = np.repeat(".", vv_vep.shape[0])
vv_vep = vv_vep[["Chrom", "Pos", 1, "MusculusReference", "MajorAllele", "MinorAllele", 2, 3, 4]]

out = []
c = 0
for index, row in vv_vep.iterrows():
    c += 1
    if row["MusculusReference"] == row["MajorAllele"]:
        out.append(list(row[["Chrom", "Pos", 1, "MusculusReference", "MinorAllele", 2, 3, 4]]))
    elif row["MusculusReference"] == row["MinorAllele"]:
        out.append(list(row[["Chrom", "Pos", 1, "MusculusReference", "MajorAllele", 2, 3, 4]]))

    if c % 600000 == 0:
        df = pd.DataFrame(out)
        df.to_csv("Mus_VEP/Poly_Mmd_VEP" + str(c//600000) + ".vcf", sep = "\t", header = False, index = False)
        out = []
# Out:
# C:\Users\astar\AppData\Local\Temp\ipykernel_8784\2848626596.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vv_vep["Chrom"] = [x.split(":")[0].replace("chr", "") for x in vv["Position"]]
# C:\Users\astar\AppData\Local\Temp\ipykernel_8784\2848626596.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vv_vep["Pos"] = [x.split(":")[1] for x in vv["Position"]]
# C:\Users\astar\AppData\Local\Temp\ipykernel_8784\2848626596.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vv_vep[1] = np.repeat(".", vv_vep.shape[0])
# C:\Users\astar\AppData\Local\Temp\ipykernel_8784\2848626596.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vv_vep[2] = np.repeat(".", vv_vep.shape[0])
# C:\Users\astar\AppData\Local\Temp\ipykernel_8784\2848626596.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vv_vep[3] = np.repeat(".", vv_vep.shape[0])
# C:\Users\astar\AppData\Local\Temp\ipykernel_8784\2848626596.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vv_vep[4] = np.repeat(".", vv_vep.shape[0])

# %%
v_vep = v[["Position", "Domesticus", "Spretus"]]
v_vep["Chrom"] = [x.split(":")[0].replace("chr", "") for x in v["Position"]]
v_vep["Pos"] = [x.split(":")[1] for x in v["Position"]]

v_vep[1] = np.repeat(".", v_vep.shape[0])
v_vep[2] = np.repeat(".", v_vep.shape[0])
v_vep[3] = np.repeat(".", v_vep.shape[0])
v_vep[4] = np.repeat(".", v_vep.shape[0])
v_vep = v_vep[["Chrom", "Pos", 1, "Domesticus", "Spretus", 2, 3, 4]]

out = []
c = 0
for index, row in v_vep.iterrows():
    c += 1
    out.append(row)
    if c % 600000 == 0:
        df = pd.DataFrame(out)
        df.to_csv("Mus_VEP/Fixed_Mmd_VEP" + str(c//600000) + ".vcf", sep = "\t", header = False, index = False)
        out = []
# Out:
# C:\Users\astar\AppData\Local\Temp\ipykernel_8784\2347643931.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   v_vep["Chrom"] = [x.split(":")[0].replace("chr", "") for x in v["Position"]]
# C:\Users\astar\AppData\Local\Temp\ipykernel_8784\2347643931.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   v_vep["Pos"] = [x.split(":")[1] for x in v["Position"]]
# C:\Users\astar\AppData\Local\Temp\ipykernel_8784\2347643931.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   v_vep[1] = np.repeat(".", v_vep.shape[0])
# C:\Users\astar\AppData\Local\Temp\ipykernel_8784\2347643931.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   v_vep[2] = np.repeat(".", v_vep.shape[0])
# C:\Users\astar\AppData\Local\Temp\ipykernel_8784\2347643931.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   v_vep[3] = np.repeat(".", v_vep.shape[0])
# C:\Users\astar\AppData\Local\Temp\ipykernel_8784\2347643931.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   v_vep[4] = np.repeat(".", v_vep.shape[0])

# %%
vv = vv[vv["SpecSup447"] > 50]
v = v[v["SpecSup447"] > 50]
vv = vv[(vv["UnfoldedMAF"] < 0.75) & (vv["UnfoldedMAF"] > 0.25)]
v = v[v["Derived"].isin(["MusDer"])]

# %%
fisher_exact([[305, 1659], [137, 853]])
# Out:
# SignificanceResult(statistic=1.1446742607234153, pvalue=0.2298185318963617)

# %%
vk
# Out:
#                Position Domesticus               Musculus           Castaneus  \
# 7682324  chr17:15766597          C                      C                   C
# 7682325  chr17:15766676          A                      A                   A
# 7682326  chr17:15766704          C                      C                   C
# 7682328  chr17:15766801          G                      G                   G
# 7682330  chr17:15767044          T                      T                   T
# 7682331  chr17:15767048          C                      C                   C
# 7682333  chr17:15767406          A                      A                   A
# 7682356  chr17:15768278          T                      T                   T
# 7682357  chr17:15768311          A                      A                   A
# 7682362  chr17:15768368          G                      G                   G
# 7682365  chr17:15768444          A    G,0.31,13;A,0.69,29  A,0.45,9;G,0.55,11
# 7682368  chr17:15768511          G                      G                   G
# 7682370  chr17:15768556          A                      A                   A
# 7682371  chr17:15768583          A  A,0.682,30;G,0.318,14    A,0.9,18;G,0.1,2
# 7682375  chr17:15768793          C                      C                   C
# 7682376  chr17:15768797          A                      A                   A
# 7682379  chr17:15768897          A                      A                   A
# 7682382  chr17:15768951          A                      A                   A
# 7682384  chr17:15769074          T  T,0.682,30;C,0.318,14   T,0.5,10;C,0.5,10
# 7682387  chr17:15769159          A  C,0.364,16;A,0.636,28  A,0.45,9;C,0.55,11
# 7682388  chr17:15769160          G                      G                   G
# 7682389  chr17:15769166          G                      G                   G
# 7682390  chr17:15769170          G                      G                   G
# 7682391  chr17:15769201          C                      C                   C
# 7682393  chr17:15769222          A                      A                   A
# 7682394  chr17:15769284          T                      T                   T
# 7682397  chr17:15769395          A                      A                   A
# 7682398  chr17:15769413          C                      C                   C
# 7682425  chr17:15774851          T  T,0.273,12;G,0.727,32  T,0.45,9;G,0.55,11
# 7682426  chr17:15774911          A    G,0.75,33;A,0.25,11  A,0.45,9;G,0.55,11
# 7682427  chr17:15774973          G  G,0.273,12;A,0.727,32  G,0.45,9;A,0.55,11
# 7682430  chr17:15775144          C                      C                   C
# 7682431  chr17:15775152          T                      T                   T
# 7682435  chr17:15775668          C                      C                   C
# 7682436  chr17:15775949          G                      G                   G
# 7682447  chr17:15776574          C                      C                   C
# 7682455  chr17:15777588          A                      A                   A
# 7682457  chr17:15777628          A                      A                   A
# 7682461  chr17:15777932          A                      A                   A
# 7682462  chr17:15777935          G                      G                   G
# 7682463  chr17:15777937          A                      A                   A
# 7682464  chr17:15777991          G                      G                   G
# 7682466  chr17:15778086          G   G,0.977,43;A,0.023,1    G,0.8,16;A,0.2,4
# 7682467  chr17:15778107          G                      G                   G
# 7682468  chr17:15778166          A                      A                   A
# 7682472  chr17:15778631          G                      G                   G
# 7682474  chr17:15778642          A                      A                   A
# 7682477  chr17:15778705          T                      T                   T
# 7682509  chr17:15782852          G                      G                   G
#
#         Spretus Caroli Pahari Derived  PhyloP447 NearestGene  NearestDist  \
# 7682324       T      T      T  MusDer      0.805       Prdm9        16972
# 7682325       G      G      G  MusDer      0.544       Prdm9        16893
# 7682326       T      T      T  MusDer      0.675       Prdm9        16865
# 7682328       A      A      A  MusDer      0.258       Prdm9        16768
# 7682330       C      C      C  MusDer     -0.171       Prdm9        16525
# 7682331       T      T      T  MusDer     -0.522       Prdm9        16521
# 7682333       C      C      C  MusDer      0.020       Prdm9        16163
# 7682356       G      G      .  MusDer     -0.491       Prdm9        15291
# 7682357       T      T      .  MusDer      7.332       Prdm9        15258
# 7682362       T      T      .  MusDer      7.334       Prdm9        15201
# 7682365       G      G      .  MusDer      2.976       Prdm9        15125
# 7682368       A      A      .  MusDer     -0.308       Prdm9        15058
# 7682370       G      G      .  MusDer     -0.646       Prdm9        15013
# 7682371       G      G      .  MusDer     -0.017       Prdm9        14986
# 7682375       A      A      .  MusDer     -0.734       Prdm9        14776
# 7682376       G      G      .  MusDer      6.674       Prdm9        14772
# 7682379       G      G      .  MusDer      0.179       Prdm9        14672
# 7682382       G      G      .  MusDer      3.533       Prdm9        14618
# 7682384       C      C      .  MusDer      1.324       Prdm9        14495
# 7682387       C      C      .  MusDer      0.064       Prdm9        14410
# 7682388       T      T      .  MusDer      4.110       Prdm9        14409
# 7682389       A      A      .  MusDer      0.337       Prdm9        14403
# 7682390       A      A      .  MusDer     -0.851       Prdm9        14399
# 7682391       T      T      .  MusDer      1.317       Prdm9        14368
# 7682393       T      T      .  MusDer     -0.127       Prdm9        14347
# 7682394       C      C      .  MusDer      4.151       Prdm9        14285
# 7682397       G      G      .  MusDer     -5.987       Prdm9        14174
# 7682398       G      G      .  MusDer      6.665       Prdm9        14156
# 7682425       G      G      G  MusDer     -1.003       Prdm9         8718
# 7682426       G      G      G  MusDer     -0.246       Prdm9         8658
# 7682427       A      A      A  MusDer     -1.042       Prdm9         8596
# 7682430       T      T      T  MusDer      0.997       Prdm9         8425
# 7682431       C      C      C  MusDer     -4.687       Prdm9         8417
# 7682435       G      G      G  MusDer     -0.346       Prdm9         7901
# 7682436       T      T      T  MusDer     -0.260       Prdm9         7620
# 7682447       T      T      T  MusDer      0.569       Prdm9         6995
# 7682455       G      G      G  MusDer      0.132       Prdm9         5981
# 7682457       G      G      G  MusDer     -0.357       Prdm9         5941
# 7682461       G      G      G  MusDer     -0.064       Prdm9         5637
# 7682462       A      A      A  MusDer      1.444       Prdm9         5634
# 7682463       G      G      G  MusDer     -0.204       Prdm9         5632
# 7682464       A      A      A  MusDer      0.241       Prdm9         5578
# 7682466       A      A      A  MusDer      1.038       Prdm9         5483
# 7682467       A      A      A  MusDer      0.291       Prdm9         5462
# 7682468       G      G      G  MusDer     -1.819       Prdm9         5403
# 7682472       C      C      C  MusDer     -0.706       Prdm9         4938
# 7682474       G      G      A  MusDer    -20.000       Prdm9         4927
# 7682477       A      A      A  MusDer      1.011       Prdm9         4864
# 7682509       A      A      G  MusDer      0.184       Prdm9          717
#
#          SpecSup447 FixedOrPoly MAFMaxAcrossAncestry UnfoldedMAF
# 7682324       148.0       Fixed                    .           .
# 7682325       236.0       Fixed                    .           .
# 7682326       332.0       Fixed                    .           .
# 7682328       325.0       Fixed                    .           .
# 7682330       338.0       Fixed                    .           .
# 7682331       234.0       Fixed                    .           .
# 7682333       337.0       Fixed                    .           .
# 7682356       435.0       Fixed                    .           .
# 7682357       439.0       Fixed                    .           .
# 7682362       440.0       Fixed                    .           .
# 7682365       431.0       Fixed                    .           .
# 7682368       440.0       Fixed                    .           .
# 7682370       436.0       Fixed                    .           .
# 7682371       337.0       Fixed                    .           .
# 7682375       436.0       Fixed                    .           .
# 7682376       436.0       Fixed                    .           .
# 7682379       424.0       Fixed                    .           .
# 7682382       441.0       Fixed                    .           .
# 7682384       401.0       Fixed                    .           .
# 7682387       434.0       Fixed                    .           .
# 7682388       434.0       Fixed                    .           .
# 7682389       434.0       Fixed                    .           .
# 7682390       439.0       Fixed                    .           .
# 7682391       421.0       Fixed                    .           .
# 7682393       247.0       Fixed                    .           .
# 7682394       437.0       Fixed                    .           .
# 7682397       439.0       Fixed                    .           .
# 7682398       438.0       Fixed                    .           .
# 7682425       412.0       Fixed                    .           .
# 7682426       422.0       Fixed                    .           .
# 7682427       438.0       Fixed                    .           .
# 7682430       433.0       Fixed                    .           .
# 7682431       436.0       Fixed                    .           .
# 7682435       431.0       Fixed                    .           .
# 7682436       428.0       Fixed                    .           .
# 7682447       400.0       Fixed                    .           .
# 7682455       434.0       Fixed                    .           .
# 7682457       435.0       Fixed                    .           .
# 7682461       382.0       Fixed                    .           .
# 7682462       393.0       Fixed                    .           .
# 7682463       388.0       Fixed                    .           .
# 7682464       380.0       Fixed                    .           .
# 7682466       176.0       Fixed                    .           .
# 7682467       423.0       Fixed                    .           .
# 7682468       416.0       Fixed                    .           .
# 7682472       360.0       Fixed                    .           .
# 7682474       381.0       Fixed                    .           .
# 7682477       409.0       Fixed                    .           .
# 7682509       369.0       Fixed                    .           .

# %%
vk
# Out:
#                    Position Domesticus              Musculus  \
# NearestGene
# Pdgfa        chr5:138895303          A                     A
# Pdgfa        chr5:138897369          G                     G
# Pdgfa        chr5:138897960          T                     T
# Pdgfa        chr5:138898359          T                     T
# Pdgfa        chr5:138900182          A                     A
# ...                     ...        ...                   ...
# Pdgfa        chr5:139041592          G                     G
# Pdgfa        chr5:139042855          G                     G
# Pdgfa        chr5:139043336          T                     T
# Pdgfa        chr5:139043563          G  G,0.136,6;A,0.864,38
# Pdgfa        chr5:139043761          T                     T
#
#                       Castaneus Spretus Caroli Pahari Derived  PhyloP447  \
# NearestGene
# Pdgfa                         A       G      G      G  MusDer      0.125
# Pdgfa          G,0.8,16;T,0.2,4       T      T      T  MusDer     -0.066
# Pdgfa          T,0.9,18;C,0.1,2       C      C      C  MusDer      2.133
# Pdgfa                         T       G      G      G  MusDer     -2.891
# Pdgfa                         A       G      G      G  MusDer     -0.459
# ...                         ...     ...    ...    ...     ...        ...
# Pdgfa        G,0.85,17;A,0.15,3       A      A      A  MusDer     -0.153
# Pdgfa                         G       A      A      A  MusDer      2.037
# Pdgfa                         T       C      C      C  MusDer      1.353
# Pdgfa         G,0.5,10;A,0.5,10       A      A      A  MusDer      0.474
# Pdgfa                         T       C      C      C  MusDer      0.743
#
#             NearestGene  NearestDist  SpecSup447 FixedOrPoly  \
# NearestGene
# Pdgfa             Pdgfa        84412        92.0       Fixed
# Pdgfa             Pdgfa        82346       325.0       Fixed
# Pdgfa             Pdgfa        81755       146.0       Fixed
# Pdgfa             Pdgfa        81356       363.0       Fixed
# Pdgfa             Pdgfa        79533       340.0       Fixed
# ...                 ...          ...         ...         ...
# Pdgfa             Pdgfa        58735       100.0       Fixed
# Pdgfa             Pdgfa        59998       430.0       Fixed
# Pdgfa             Pdgfa        60479       407.0       Fixed
# Pdgfa             Pdgfa        60706       374.0       Fixed
# Pdgfa             Pdgfa        60904       307.0       Fixed
#
#             MAFMaxAcrossAncestry UnfoldedMAF
# NearestGene
# Pdgfa                          .           .
# Pdgfa                          .           .
# Pdgfa                          .           .
# Pdgfa                          .           .
# Pdgfa                          .           .
# ...                          ...         ...
# Pdgfa                          .           .
# Pdgfa                          .           .
# Pdgfa                          .           .
# Pdgfa                          .           .
# Pdgfa                          .           .
#
# [122 rows x 15 columns]

# %%
vk = v[v["NearestGene"].isin(["Epcam"])]
vvk = vv[vv["NearestGene"].isin(["Epcam"])]
vvv = prepare_alpha(vk, vvk)
compute_alpha_new(vvv, plot = True)
mwu(vk["PhyloP447"], vvk["PhyloP447"])
# Out:
# C:\Users\astar\PosSelect_ForPub\PosSelect_Functions_Old.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   poly["FixedOrPoly"] = y
# C:\Users\astar\PosSelect_ForPub\PosSelect_Functions_Old.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fixed["FixedOrPoly"] = x
# C:\Users\astar\PosSelect_ForPub\PosSelect_Functions_Old.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fixed["MAFMaxAcrossAncestry"] = z
# C:\Users\astar\PosSelect_ForPub\PosSelect_Functions_Old.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fixed["UnfoldedMAF"] = z
# MannwhitneyuResult(statistic=3005.0, pvalue=0.02083681399115391)

# %%
metric = "PhyloP447"
c = 0
out = []
v.index = v["NearestGene"]
vv.index = vv["NearestGene"]
vv = vv[(vv["MAFMaxAcrossAncestry"] < 0.75) & (vv["MAFMaxAcrossAncestry"] > 0.25)]
for gene in np.unique(np.intersect1d(v["NearestGene"], vv["NearestGene"])):
    if c%1000 == 0:
        print(c)
    vk = v.loc[gene].copy()
    vvk = vv.loc[gene].copy()
    if len(vk.index) >= 50 and len(vvk.index) >= 25:
        x2 = [np.float64(x) for x in list(vk[metric])]
        yvals2 = [np.float64(j) for j in list(vvk[metric])]
        yvals2.sort()
        vvv = prepare_alpha(vk, vvk, stat = metric)
        for cuttt in [0.5, 0.6, 0.7, 0.8, 0.9]:
            cutoff = yvals2[int(floor((len(yvals2)*cuttt)))]
            alpha = compute_alpha_cutoff(vvv, dn_cut = 0.05, plot = False, cutoff = cutoff)

            table1 = alpha[2]
            table2 = alpha[3]
            out.append([gene, np.median(x2), len(x2), np.median(yvals2), len(yvals2), (fisher_exact(table1)[1] + fisher_exact(table2)[1])/2, mwu(x2, yvals2)[1], (fisher_exact(table1, alternative = "greater")[1] + fisher_exact(table2, alternative = "greater")[1])/2, mwu(x2, yvals2, alternative = "greater")[1], alpha[0], alpha[1], table1, table2, cuttt])

    c += 1


from statsmodels.stats.multitest import fdrcorrection
df = pd.DataFrame(out)
df = df.sort_values(5)
#df["FDR"] = fdrcorrection(df[5])[1]
df.columns = ["Gene", "Median Fixed PhyloP", "Number Fixed Variants", "Median Polymorphic PhyloP", "Number Polymorphic Variants", "Fisher exact p-value", "MWU p-value", "Fisher exact p-value; alt greater", "MWU p-value; alt greater", "alpha", "Cutoff", "[[dc1, du1], [pc1, pu1]]", "[[dc2, du2], [pc2, pu2]]", "Proportion"]
df.to_csv("Mus_musculus_domesticus_PhyloP447_NonCoding_PerGene_SpecSup75_MAF0.25-0.75.csv", index = False)
# Out:
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000

# %%
df = df[df["Proportion"] == 0.9].sort_values("Fisher exact p-value; alt greater")
df
# Out:
#           Gene  Median Fixed PhyloP  Number Fixed Variants  \
# 35689   Snap91               0.2715                    198
# 28474    Pdgfa              -0.0110                    122
# 12519    Epcam               0.2945                     70
# 24904    Mrpl1               0.4150                    101
# 12974     Eya2               0.1240                    297
# ...        ...                  ...                    ...
# 35899   Sohlh2               0.0650                     69
# 39514     Tpte               0.0360                     56
# 4294     Arl8b               0.0475                     54
# 32379    Rnf17               0.1325                     78
# 35134  Slc47a1              -0.1390                     59
#
#        Median Polymorphic PhyloP  Number Polymorphic Variants  \
# 35689                     0.0990                          237
# 28474                    -0.1255                           90
# 12519                     0.0385                           70
# 24904                     0.1510                          119
# 12974                     0.0260                          283
# ...                          ...                          ...
# 35899                     0.3240                           34
# 39514                     0.1920                           65
# 4294                      0.0360                           66
# 32379                     0.2410                           31
# 35134                     0.1090                           27
#
#        Fisher exact p-value  MWU p-value  Fisher exact p-value; alt greater  \
# 35689              0.000070     0.005978                           0.000051
# 28474              0.000431     0.054606                           0.000271
# 12519              0.000631     0.020837                           0.000316
# 24904              0.001249     0.017791                           0.000840
# 12974              0.001921     0.162288                           0.000976
# ...                     ...          ...                                ...
# 35899              0.022163     0.044509                           1.000000
# 39514              0.022319     0.487697                           1.000000
# 4294               0.024007     0.845253                           1.000000
# 32379              0.013534     0.375280                           1.000000
# 35134              0.062307     0.024924                           1.000000
#
#        MWU p-value; alt greater      alpha  Cutoff [[dc1, du1], [pc1, pu1]]  \
# 35689                  0.002989   0.656011   1.036   [[48, 150], [23, 214]]
# 28474                  0.027303   0.750753   0.712      [[36, 86], [8, 82]]
# 12519                  0.010418   0.803675   0.798      [[24, 46], [6, 64]]
# 24904                  0.008896   0.706739   1.182    [[27, 74], [11, 108]]
# 12974                  0.081144   0.538530   1.473   [[58, 239], [28, 255]]
# ...                         ...        ...     ...                      ...
# 35899                  0.978115  -9.020161   2.430       [[0, 69], [3, 31]]
# 39514                  0.757778  -6.189407   2.956       [[0, 56], [6, 59]]
# 4294                   0.422627  -5.822404   1.622       [[0, 54], [6, 60]]
# 32379                  0.814164 -11.501847   2.785       [[0, 78], [3, 28]]
# 35134                  0.987835  -7.261538   1.727       [[0, 59], [2, 25]]
#
#       [[dc2, du2], [pc2, pu2]]  Proportion
# 35689   [[48, 150], [24, 213]]         0.9
# 28474      [[36, 86], [9, 81]]         0.9
# 12519      [[24, 46], [7, 63]]         0.9
# 24904    [[27, 74], [12, 107]]         0.9
# 12974   [[58, 239], [29, 254]]         0.9
# ...                        ...         ...
# 35899       [[0, 69], [4, 30]]         0.9
# 39514       [[0, 56], [7, 58]]         0.9
# 4294        [[0, 54], [7, 59]]         0.9
# 32379       [[0, 78], [4, 27]]         0.9
# 35134       [[0, 59], [3, 24]]         0.9
#
# [8550 rows x 14 columns]

# %%
df = df[df["Proportion"] == 0.9].sort_values("Fisher exact p-value; alt greater")
df.to_csv("Bleh.csv")

# %%
df = pd.DataFrame(out)
df = df.sort_values(5)
#df["FDR"] = fdrcorrection(df[5])[1]
df.columns = ["Gene", "Median Fixed PhyloP", "Number Fixed Variants", "Median Polymorphic PhyloP", "Number Polymorphic Variants", "Fisher exact p-value", "MWU p-value", "Fisher exact p-value; alt greater", "MWU p-value; alt greater", "alpha", "Cutoff", "[[dc1, du1], [pc1, pu1]]", "[[dc2, du2], [pc2, pu2]]", "Proportion"]
df = df.sort_values("Fisher exact p-value; alt greater")
df.head(50)
# Out:
#                 Gene  Median Fixed PhyloP  Number Fixed Variants  \
# 10365           Gas2               0.0810                    327
# 19489          Pdgfa              -0.0110                    122
# 20016           Pkp1               0.0855                    182
# 17029          Mrpl1               0.4150                    101
# 8819            Eya2               0.1240                    297
# 18023          Nipa2               0.1100                    115
# 17278           Murc               0.2685                    276
# 12916          Gtdc1               0.3120                   1523
# 14690         Kcnmb4               0.2490                    322
# 959    5031425E22Rik               0.2630                    285
# 11031        Gm11042               0.0760                    609
# 17028          Mrpl1               0.4150                    101
# 3005            Asb4               0.2610                    211
# 14115       Irak1bp1               0.2310                    533
# 3189          Atp1b1              -0.0055                    408
# 1284        AI593442               0.1310                   1017
# 2487           Anxa1               0.0790                    785
# 21165            Ptn               0.0510                    571
# 676    4930449E01Rik               0.1525                    516
# 18243          Npas3               0.2505                   1658
# 22759         Samd13               0.1440                    168
# 24360           Smc5               0.2500                    246
# 8818            Eya2               0.1240                    297
# 2235            Alx1               0.0860                    784
# 22349            Rpe               0.2590                    241
# 19853           Pigk               0.1180                    185
# 17830          Nek11               0.2030                    138
# 1840            Add3               0.4750                    314
# 9702            Fign               0.1990                   2258
# 19578         Pdzrn4               0.1310                    579
# 19068           Pan3               0.1780                    345
# 2104           Akap6               0.3160                    665
# 18045         Nkain2               0.0770                   1079
# 18721       Olfr1324               0.4310                    246
# 7700            Dsel               0.0745                   1374
# 10808        Gm10234               0.1540                    445
# 12740         Greb1l               0.4740                    386
# 19854           Pigk               0.1180                    185
# 16222         Map4k4               0.0610                    381
# 21441          Rab38               0.0750                    765
# 21443          Rab38               0.0750                    765
# 677    4930449E01Rik               0.1525                    516
# 9395            Faxc               0.2170                    483
# 19270         Pcdh15              -0.0520                   1537
# 3297          Atrnl1               0.1250                    609
# 363    1810049J17Rik               0.1120                    315
# 8100          Egfem1               0.1780                    955
# 18412          Nrip1               0.2130                    551
# 12563         Gpr110               0.0690                    175
# 1265        AI317395               0.4250                    117
#
#        Median Polymorphic PhyloP  Number Polymorphic Variants  \
# 10365                    -0.1790                           98
# 19489                    -0.1255                           90
# 20016                    -0.1810                           89
# 17029                     0.1510                          119
# 8819                      0.0260                          283
# 18023                    -0.0730                           67
# 17278                     0.1365                          392
# 12916                     0.1760                          540
# 14690                     0.0300                          165
# 959                       0.2130                          270
# 11031                    -0.0010                          545
# 17028                     0.1510                          119
# 3005                     -0.0020                           89
# 14115                     0.0735                          372
# 3189                     -0.0340                          207
# 1284                      0.0740                          641
# 2487                      0.0205                          874
# 21165                    -0.0445                          364
# 676                      -0.0030                          257
# 18243                     0.2220                         1356
# 22759                     0.0080                           58
# 24360                     0.0790                          212
# 8818                      0.0260                          283
# 2235                     -0.0320                          262
# 22349                     0.1305                          224
# 19853                     0.1200                          303
# 17830                    -0.0340                          200
# 1840                      0.2500                          203
# 9702                      0.1360                          647
# 19578                     0.0200                          729
# 19068                     0.0005                          134
# 2104                      0.2540                          742
# 18045                    -0.0115                          630
# 18721                     0.2190                           57
# 7700                      0.0050                         1539
# 10808                     0.0715                          400
# 12740                     0.1830                          117
# 19854                     0.1200                          303
# 16222                    -0.0240                          153
# 21441                     0.0165                          530
# 21443                     0.0165                          530
# 677                      -0.0030                          257
# 9395                      0.0945                          426
# 19270                    -0.1240                         1186
# 3297                      0.0660                          924
# 363                       0.0110                          242
# 8100                      0.0980                          967
# 18412                     0.0720                          486
# 12563                    -0.0410                          163
# 1265                      0.0640                           75
#
#        Fisher exact p-value  MWU p-value  Fisher exact p-value; alt greater  \
# 10365              0.000290     0.003939                           0.000187
# 19489              0.000431     0.054606                           0.000271
# 20016              0.000950     0.018073                           0.000638
# 17029              0.001249     0.017791                           0.000840
# 8819               0.001921     0.162288                           0.000976
# 18023              0.001691     0.130007                           0.001094
# 17278              0.001991     0.009179                           0.001214
# 12916              0.002399     0.037944                           0.001265
# 14690              0.002158     0.006762                           0.001375
# 959                0.003027     0.075208                           0.001591
# 11031              0.003012     0.025271                           0.001649
# 17028              0.002669     0.017791                           0.001659
# 3005               0.002595     0.090579                           0.001768
# 14115              0.003128     0.017203                           0.001842
# 3189               0.003030     0.163903                           0.001878
# 1284               0.003630     0.074994                           0.001955
# 2487               0.003774     0.018596                           0.002030
# 21165              0.003690     0.098009                           0.002095
# 676                0.003674     0.027570                           0.002100
# 18243              0.004327     0.210567                           0.002344
# 22759              0.004262     0.170454                           0.002491
# 24360              0.004494     0.115092                           0.002514
# 8818               0.004811     0.162288                           0.002771
# 2235               0.005470     0.025521                           0.002958
# 22349              0.005081     0.318779                           0.003040
# 19853              0.005539     0.074400                           0.003332
# 17830              0.006299     0.007225                           0.003339
# 1840               0.006249     0.124742                           0.003509
# 9702               0.006573     0.067349                           0.003551
# 19578              0.006460     0.007678                           0.003569
# 19068              0.006059     0.003081                           0.003683
# 2104               0.006500     0.078368                           0.003722
# 18045              0.007111     0.016574                           0.003808
# 18721              0.006126     0.028861                           0.003876
# 7700               0.007471     0.046182                           0.003990
# 10808              0.006936     0.056136                           0.004083
# 12740              0.007115     0.022872                           0.004237
# 19854              0.007485     0.074400                           0.004523
# 16222              0.008245     0.120809                           0.004601
# 21441              0.008454     0.044077                           0.004675
# 21443              0.008647     0.044077                           0.004695
# 677                0.009131     0.027570                           0.004827
# 9395               0.010188     0.136901                           0.005177
# 19270              0.010054     0.102199                           0.005196
# 3297               0.009632     0.051666                           0.005199
# 363                0.009515     0.017248                           0.005516
# 8100               0.010595     0.021189                           0.005752
# 18412              0.011436     0.054222                           0.005784
# 12563              0.011140     0.004549                           0.005810
# 1265               0.010484     0.062417                           0.006093
#
#        MWU p-value; alt greater     alpha  Cutoff    [[dc1, du1], [pc1, pu1]]  \
# 10365                  0.001970  0.580611  -0.176       [[229, 98], [48, 50]]
# 19489                  0.027303  0.750753   0.712         [[36, 86], [8, 82]]
# 20016                  0.009036  0.585190  -0.092       [[112, 70], [35, 54]]
# 17029                  0.008896  0.706739   1.182       [[27, 74], [11, 108]]
# 8819                   0.081144  0.538530   1.473      [[58, 239], [28, 255]]
# 18023                  0.065004  0.671820   0.330        [[50, 65], [13, 54]]
# 17278                  0.004590  0.432822   0.847      [[85, 191], [78, 314]]
# 12916                  0.018972  0.267990   0.366    [[723, 800], [214, 326]]
# 14690                  0.003381  0.451883   0.030      [[208, 114], [82, 83]]
# 959                    0.037604  0.534431   1.272      [[54, 231], [26, 244]]
# 11031                  0.012635  0.300041   0.103    [[296, 313], [217, 328]]
# 17028                  0.008896  0.608752   0.720        [[39, 62], [23, 96]]
# 3005                   0.045289  0.544869  -0.002       [[144, 67], [44, 45]]
# 14115                  0.008601  0.332741   0.075    [[319, 214], [185, 187]]
# 3189                   0.081952  0.534922   0.740      [[78, 330], [20, 187]]
# 1284                   0.037497  0.368191   1.169     [[153, 864], [64, 577]]
# 2487                   0.009298  0.263254   0.351    [[289, 496], [262, 612]]
# 21165                  0.049004  0.326763  -0.044    [[340, 231], [181, 183]]
# 676                    0.013785  0.364264   0.133    [[263, 253], [102, 155]]
# 18243                  0.105284  0.224207   1.073  [[404, 1254], [271, 1085]]
# 22759                  0.085227  0.730036   0.726        [[47, 121], [5, 53]]
# 24360                  0.057546  0.423477   0.084     [[155, 91], [105, 107]]
# 8818                   0.081144  0.426255   0.797      [[90, 207], [56, 227]]
# 2235                   0.012761  0.333446  -0.023    [[469, 315], [130, 132]]
# 22349                  0.159389  0.539067   1.323      [[47, 194], [22, 202]]
# 19853                  0.037200  0.453703   0.721      [[58, 127], [60, 243]]
# 17830                  0.003613  0.471947  -0.033       [[90, 48], [99, 101]]
# 1840                   0.062371  0.397969   0.250    [[195, 119], [101, 102]]
# 9702                   0.033674  0.230723   0.515   [[807, 1451], [193, 454]]
# 19578                  0.003839  0.305615   0.677    [[152, 427], [144, 585]]
# 19068                  0.001541  0.487112   0.591     [[112, 233], [26, 108]]
# 2104                   0.039184  0.361900   1.715      [[99, 566], [74, 668]]
# 18045                  0.008287  0.239343  -0.010    [[612, 467], [314, 316]]
# 18721                  0.014430  0.567925   0.279       [[148, 98], [22, 35]]
# 7700                   0.023091  0.181337   0.005    [[755, 619], [769, 770]]
# 10808                  0.028068  0.359338   0.699     [[123, 322], [78, 322]]
# 12740                  0.011436  0.443467   0.183      [[248, 138], [58, 59]]
# 19854                  0.037200  0.520299   1.221      [[35, 150], [30, 273]]
# 16222                  0.060405  0.421596   0.235     [[161, 220], [45, 108]]
# 21441                  0.022038  0.262635   0.118    [[364, 401], [211, 319]]
# 21443                  0.022038  0.302634   0.536    [[201, 564], [105, 425]]
# 677                    0.013785  0.350255   0.328     [[206, 310], [77, 180]]
# 9395                   0.068451  0.296589   0.096    [[283, 200], [212, 214]]
# 19270                  0.051100  0.182445  -0.123    [[844, 693], [592, 594]]
# 3297                   0.025833  0.251739   0.454    [[222, 387], [277, 647]]
# 363                    0.008624  0.410696   0.772      [[94, 221], [48, 194]]
# 8100                   0.010595  0.209884   0.098    [[533, 422], [482, 485]]
# 18412                  0.027111  0.289871   0.445    [[207, 344], [145, 341]]
# 12563                  0.002275  0.487720   0.496      [[56, 119], [31, 132]]
# 1265                   0.031209  0.555398   0.064        [[81, 36], [37, 38]]
#
#          [[dc2, du2], [pc2, pu2]]  Proportion
# 10365       [[229, 98], [49, 49]]         0.5
# 19489         [[36, 86], [9, 81]]         0.9
# 20016       [[112, 70], [36, 53]]         0.6
# 17029       [[27, 74], [12, 107]]         0.9
# 8819       [[58, 239], [29, 254]]         0.9
# 18023        [[50, 65], [14, 53]]         0.8
# 17278      [[85, 191], [80, 312]]         0.8
# 12916    [[723, 800], [216, 324]]         0.6
# 14690      [[208, 114], [83, 82]]         0.5
# 959        [[54, 231], [27, 243]]         0.9
# 11031    [[297, 312], [218, 327]]         0.6
# 17028        [[39, 62], [24, 95]]         0.8
# 3005        [[146, 65], [45, 44]]         0.5
# 14115    [[319, 214], [186, 186]]         0.5
# 3189       [[78, 330], [21, 186]]         0.9
# 1284      [[153, 864], [65, 576]]         0.9
# 2487     [[289, 496], [263, 611]]         0.7
# 21165    [[341, 230], [182, 182]]         0.5
# 676      [[264, 252], [103, 154]]         0.6
# 18243  [[405, 1253], [272, 1084]]         0.8
# 22759        [[47, 121], [6, 52]]         0.9
# 24360     [[156, 90], [106, 106]]         0.5
# 8818       [[90, 207], [57, 226]]         0.8
# 2235     [[469, 315], [131, 131]]         0.5
# 22349      [[47, 194], [23, 201]]         0.9
# 19853      [[58, 127], [61, 242]]         0.8
# 17830      [[90, 48], [100, 100]]         0.5
# 1840     [[197, 117], [102, 101]]         0.5
# 9702    [[808, 1450], [195, 452]]         0.7
# 19578    [[153, 426], [146, 583]]         0.8
# 19068     [[112, 233], [27, 107]]         0.8
# 2104       [[99, 566], [75, 667]]         0.9
# 18045    [[612, 467], [315, 315]]         0.5
# 18721       [[148, 98], [23, 34]]         0.6
# 7700     [[756, 618], [770, 769]]         0.5
# 10808     [[124, 321], [80, 320]]         0.8
# 12740      [[248, 138], [59, 58]]         0.5
# 19854      [[35, 150], [31, 272]]         0.9
# 16222     [[161, 220], [46, 107]]         0.7
# 21441    [[364, 401], [214, 316]]         0.6
# 21443    [[201, 564], [106, 424]]         0.8
# 677       [[206, 310], [78, 179]]         0.7
# 9395     [[283, 200], [213, 213]]         0.5
# 19270    [[846, 691], [593, 593]]         0.5
# 3297     [[222, 387], [278, 646]]         0.7
# 363        [[94, 221], [49, 193]]         0.8
# 8100     [[533, 422], [484, 483]]         0.5
# 18412    [[207, 344], [146, 340]]         0.7
# 12563      [[57, 118], [33, 130]]         0.8
# 1265         [[81, 36], [38, 37]]         0.5

# %%
df = pd.DataFrame(out)
df = df.sort_values(5)
#df["FDR"] = fdrcorrection(df[5])[1]
df.columns = ["Gene", "Median Fixed PhyloP", "Number Fixed Variants", "Median Polymorphic PhyloP", "Number Polymorphic Variants", "Fisher exact p-value", "MWU p-value", "Fisher exact p-value; alt greater", "MWU p-value; alt greater", "alpha", "Cutoff", "[[dc1, du1], [pc1, pu1]]", "[[dc2, du2], [pc2, pu2]]", "Proportion"]
df.sort_values("MWU p-value; alt greater").head(50)
# Out:
#                Gene  Median Fixed PhyloP  Number Fixed Variants  \
# 361   1810049J17Rik               0.1170                    316
# 363   1810049J17Rik               0.1170                    316
# 364   1810049J17Rik               0.1170                    316
# 362   1810049J17Rik               0.1170                    316
# 360   1810049J17Rik               0.1170                    316
# 676   4930449E01Rik               0.1525                    520
# 675   4930449E01Rik               0.1525                    520
# 677   4930449E01Rik               0.1525                    520
# 679   4930449E01Rik               0.1525                    520
# 678   4930449E01Rik               0.1525                    520
# 1297       AU016765               0.1460                    262
# 1298       AU016765               0.1460                    262
# 1295       AU016765               0.1460                    262
# 1296       AU016765               0.1460                    262
# 1299       AU016765               0.1460                    262
# 1851           Adgb               0.0685                    606
# 1854           Adgb               0.0685                    606
# 1853           Adgb               0.0685                    606
# 1852           Adgb               0.0685                    606
# 1850           Adgb               0.0685                    606
# 1587          Acsl6               0.2505                    122
# 1585          Acsl6               0.2505                    122
# 1589          Acsl6               0.2505                    122
# 1588          Acsl6               0.2505                    122
# 1586          Acsl6               0.2505                    122
# 1271       AI317395               0.4250                    117
# 1270       AI317395               0.4250                    117
# 1272       AI317395               0.4250                    117
# 1274       AI317395               0.4250                    117
# 1273       AI317395               0.4250                    117
# 1095  9330182L06Rik               0.1620                    487
# 1096  9330182L06Rik               0.1620                    487
# 1098  9330182L06Rik               0.1620                    487
# 1099  9330182L06Rik               0.1620                    487
# 1097  9330182L06Rik               0.1620                    487
# 1286       AI593442               0.1285                   1022
# 1287       AI593442               0.1285                   1022
# 1285       AI593442               0.1285                   1022
# 1289       AI593442               0.1285                   1022
# 1288       AI593442               0.1285                   1022
# 958   5031425E22Rik               0.2630                    285
# 959   5031425E22Rik               0.2630                    285
# 955   5031425E22Rik               0.2630                    285
# 956   5031425E22Rik               0.2630                    285
# 957   5031425E22Rik               0.2630                    285
# 2010           Agrn              -0.0110                    276
# 2014           Agrn              -0.0110                    276
# 2011           Agrn              -0.0110                    276
# 2012           Agrn              -0.0110                    276
# 2013           Agrn              -0.0110                    276
#
#       Median Polymorphic PhyloP  Number Polymorphic Variants  \
# 361                      0.0110                          242
# 363                      0.0110                          242
# 364                      0.0110                          242
# 362                      0.0110                          242
# 360                      0.0110                          242
# 676                     -0.0030                          257
# 675                     -0.0030                          257
# 677                     -0.0030                          257
# 679                     -0.0030                          257
# 678                     -0.0030                          257
# 1297                     0.0360                          221
# 1298                     0.0360                          221
# 1295                     0.0360                          221
# 1296                     0.0360                          221
# 1299                     0.0360                          221
# 1851                    -0.0135                          222
# 1854                    -0.0135                          222
# 1853                    -0.0135                          222
# 1852                    -0.0135                          222
# 1850                    -0.0135                          222
# 1587                     0.1210                           97
# 1585                     0.1210                           97
# 1589                     0.1210                           97
# 1588                     0.1210                           97
# 1586                     0.1210                           97
# 1271                     0.0640                           75
# 1270                     0.0640                           75
# 1272                     0.0640                           75
# 1274                     0.0640                           75
# 1273                     0.0640                           75
# 1095                     0.1115                          348
# 1096                     0.1115                          348
# 1098                     0.1115                          348
# 1099                     0.1115                          348
# 1097                     0.1115                          348
# 1286                     0.0730                          645
# 1287                     0.0730                          645
# 1285                     0.0730                          645
# 1289                     0.0730                          645
# 1288                     0.0730                          645
# 958                      0.2130                          270
# 959                      0.2130                          270
# 955                      0.2130                          270
# 956                      0.2130                          270
# 957                      0.2130                          270
# 2010                    -0.3705                           62
# 2014                    -0.3705                           62
# 2011                    -0.3705                           62
# 2012                    -0.3705                           62
# 2013                    -0.3705                           62
#
#       Fisher exact p-value  MWU p-value  Fisher exact p-value; alt greater  \
# 361               0.078583     0.016521                           0.044270
# 363               0.009630     0.016521                           0.005876
# 364               0.068313     0.016521                           0.040619
# 362               0.065467     0.016521                           0.035155
# 360               0.158459     0.016521                           0.084834
# 676               0.003286     0.026387                           0.001780
# 675               0.012510     0.026387                           0.006955
# 677               0.008105     0.026387                           0.004501
# 679               0.667808     0.026387                           0.349073
# 678               0.116700     0.026387                           0.065632
# 1297              0.658692     0.040930                           0.357270
# 1298              0.325288     0.040930                           0.165131
# 1295              0.019463     0.040930                           0.011852
# 1296              0.380735     0.040930                           0.199444
# 1299              0.434965     0.040930                           0.247702
# 1851              0.064520     0.056740                           0.036022
# 1854              0.310372     0.056740                           0.157565
# 1853              0.265151     0.056740                           0.139274
# 1852              0.186311     0.056740                           0.101309
# 1850              0.136169     0.056740                           0.073078
# 1587              0.161613     0.060306                           0.088423
# 1585              0.308306     0.060306                           0.171307
# 1589              1.000000     0.060306                           0.587535
# 1588              0.236563     0.060306                           0.121570
# 1586              0.279539     0.060306                           0.153291
# 1271              0.033001     0.062417                           0.020611
# 1270              0.010484     0.062417                           0.006093
# 1272              0.110738     0.062417                           0.065970
# 1274              0.340769     0.062417                           0.900519
# 1273              0.926710     0.062417                           0.497275
# 1095              0.292195     0.072668                           0.152749
# 1096              0.128343     0.072668                           0.069202
# 1098              0.081472     0.072668                           0.043809
# 1099              0.050990     0.072668                           0.028348
# 1097              0.293179     0.072668                           0.157128
# 1286              0.063741     0.074667                           0.033031
# 1287              0.316992     0.074667                           0.166622
# 1285              0.145052     0.074667                           0.076474
# 1289              0.003208     0.074667                           0.001901
# 1288              0.108957     0.074667                           0.055591
# 958               0.096350     0.075208                           0.052603
# 959               0.003027     0.075208                           0.001591
# 955               0.373695     0.075208                           0.204394
# 956               0.635263     0.075208                           0.322249
# 957               0.106607     0.075208                           0.057300
# 2010              0.102957     0.084231                           0.063075
# 2014              0.833798     0.084231                           0.410054
# 2011              0.050993     0.084231                           0.028121
# 2012              0.100050     0.084231                           0.057203
# 2013              0.025746     0.084231                           0.013432
#
#       MWU p-value; alt greater     alpha  Cutoff  [[dc1, du1], [pc1, pu1]]  \
# 361                   0.008260  0.266003   0.189   [[150, 166], [96, 146]]
# 363                   0.008260  0.408029   0.772    [[94, 222], [48, 194]]
# 364                   0.008260  0.386175   1.443    [[49, 267], [24, 218]]
# 362                   0.008260  0.291891   0.369   [[119, 197], [72, 170]]
# 360                   0.008260  0.221152   0.013  [[176, 140], [120, 122]]
# 676                   0.013193  0.368931   0.133  [[266, 254], [102, 155]]
# 675                   0.013193  0.322560  -0.003  [[310, 210], [128, 129]]
# 677                   0.013193  0.352351   0.328   [[208, 312], [77, 180]]
# 679                   0.013193  0.122548   1.397    [[58, 462], [25, 232]]
# 678                   0.013193  0.255805   0.679   [[131, 389], [51, 206]]
# 1297                  0.020465  0.087886   0.491    [[84, 178], [66, 155]]
# 1298                  0.020465  0.214653   0.722    [[63, 199], [43, 178]]
# 1295                  0.020465  0.352175   0.036  [[159, 103], [110, 111]]
# 1296                  0.020465  0.159306   0.213   [[116, 146], [88, 133]]
# 1299                  0.020465  0.213370   1.557    [[33, 229], [22, 199]]
# 1851                  0.028370  0.258244   0.121   [[286, 320], [88, 134]]
# 1854                  0.028370  0.247598   1.235    [[79, 527], [22, 200]]
# 1853                  0.028370  0.202902   0.685   [[145, 461], [44, 178]]
# 1852                  0.028370  0.205184   0.369   [[212, 394], [66, 156]]
# 1850                  0.028370  0.214180  -0.013  [[338, 268], [110, 112]]
# 1587                  0.030153  0.348787   0.467      [[49, 73], [29, 68]]
# 1585                  0.030153  0.256985   0.121      [[70, 52], [48, 49]]
# 1589                  0.030153  0.004430   1.614      [[12, 110], [9, 88]]
# 1588                  0.030153  0.348632   0.815      [[34, 88], [19, 78]]
# 1586                  0.030153  0.273665   0.311      [[58, 64], [38, 59]]
# 1271                  0.031209  0.481159   0.304      [[65, 52], [29, 46]]
# 1270                  0.031209  0.555398   0.064      [[81, 36], [37, 38]]
# 1272                  0.031209  0.405068   0.603      [[49, 68], [22, 53]]
# 1274                  0.031209 -0.746990   2.417       [[7, 110], [7, 68]]
# 1273                  0.031209  0.070953   1.210      [[24, 93], [14, 61]]
# 1095                  0.036334  0.142608   0.112  [[261, 226], [173, 175]]
# 1096                  0.036334  0.198029   0.249  [[221, 266], [139, 209]]
# 1098                  0.036334  0.261479   0.661   [[123, 364], [69, 279]]
# 1099                  0.036334  0.355196   1.136    [[71, 416], [34, 314]]
# 1097                  0.036334  0.150874   0.464  [[163, 324], [104, 244]]
# 1286                  0.037334  0.175184   0.217  [[455, 567], [257, 388]]
# 1287                  0.037334  0.105305   0.424  [[331, 691], [193, 452]]
# 1285                  0.037334  0.138429   0.073  [[549, 473], [322, 323]]
# 1289                  0.037334  0.368913   1.169   [[153, 869], [64, 581]]
# 1288                  0.037334  0.184420   0.728  [[238, 784], [127, 518]]
# 958                   0.037604  0.295375   0.911    [[74, 211], [53, 217]]
# 959                   0.037604  0.534431   1.272    [[54, 231], [26, 244]]
# 955                   0.037604  0.143599   0.217  [[153, 132], [134, 136]]
# 956                   0.037604  0.090363   0.408  [[120, 165], [107, 163]]
# 957                   0.037604  0.260664   0.568   [[104, 181], [80, 190]]
# 2010                  0.042116  0.377232  -0.352    [[168, 108], [30, 32]]
# 2014                  0.042116  0.192941   1.309      [[35, 241], [6, 56]]
# 2011                  0.042116  0.442881  -0.072    [[149, 127], [24, 38]]
# 2012                  0.042116  0.404334   0.107    [[115, 161], [18, 44]]
# 2013                  0.042116  0.541100   0.280     [[98, 178], [12, 50]]
#
#       [[dc2, du2], [pc2, pu2]]  Proportion
# 361    [[150, 166], [97, 145]]         0.6
# 363     [[94, 222], [49, 193]]         0.8
# 364     [[49, 267], [25, 217]]         0.9
# 362    [[119, 197], [73, 169]]         0.7
# 360   [[178, 138], [121, 121]]         0.5
# 676   [[267, 253], [103, 154]]         0.6
# 675   [[310, 210], [129, 128]]         0.5
# 677    [[208, 312], [78, 179]]         0.7
# 679     [[58, 462], [26, 231]]         0.9
# 678    [[131, 389], [52, 205]]         0.8
# 1297    [[84, 178], [67, 154]]         0.7
# 1298    [[63, 199], [45, 176]]         0.8
# 1295  [[159, 103], [111, 110]]         0.5
# 1296   [[116, 146], [89, 132]]         0.6
# 1299    [[33, 229], [23, 198]]         0.9
# 1851   [[286, 320], [89, 133]]         0.6
# 1854    [[79, 527], [23, 199]]         0.9
# 1853   [[145, 461], [45, 177]]         0.8
# 1852   [[212, 394], [67, 155]]         0.7
# 1850  [[338, 268], [111, 111]]         0.5
# 1587      [[49, 73], [30, 67]]         0.7
# 1585      [[70, 52], [49, 48]]         0.5
# 1589     [[12, 110], [10, 87]]         0.9
# 1588      [[34, 88], [20, 77]]         0.8
# 1586      [[58, 64], [39, 58]]         0.6
# 1271      [[65, 52], [30, 45]]         0.6
# 1270      [[81, 36], [38, 37]]         0.5
# 1272      [[49, 68], [23, 52]]         0.7
# 1274       [[7, 110], [8, 67]]         0.9
# 1273      [[24, 93], [15, 60]]         0.8
# 1095  [[262, 225], [174, 174]]         0.5
# 1096  [[222, 265], [140, 208]]         0.6
# 1098   [[123, 364], [70, 278]]         0.8
# 1099    [[71, 416], [35, 313]]         0.9
# 1097  [[164, 323], [105, 243]]         0.7
# 1286  [[457, 565], [258, 387]]         0.6
# 1287  [[331, 691], [194, 451]]         0.7
# 1285  [[549, 473], [323, 322]]         0.5
# 1289   [[153, 869], [65, 580]]         0.9
# 1288  [[238, 784], [129, 516]]         0.8
# 958     [[74, 211], [54, 216]]         0.8
# 959     [[54, 231], [27, 243]]         0.9
# 955   [[153, 132], [135, 135]]         0.5
# 956   [[120, 165], [108, 162]]         0.6
# 957    [[104, 181], [81, 189]]         0.7
# 2010    [[168, 108], [31, 31]]         0.5
# 2014      [[35, 241], [7, 55]]         0.9
# 2011    [[149, 127], [25, 37]]         0.6
# 2012    [[115, 161], [19, 43]]         0.7
# 2013     [[98, 178], [13, 49]]         0.8

# %%
vv = vv[vv["SpecSup447"] > 75]
v = v[v["SpecSup447"] > 75]
vv = vv[(vv["UnfoldedMAF"] < 0.9) & (vv["UnfoldedMAF"] > 0.1)]
v = v[v["Derived"].isin(["MusDer"])]

# %%
toss = []
for i in np.unique(vv["NearestGene"]):
    if "H2-" in i:
        toss.append(i)
        
for i in np.unique(v["NearestGene"]):
    if "H2-" in i:
        toss.append(i)

v = v[~v["NearestGene"].isin(toss)]
vv = vv[~vv["NearestGene"].isin(toss)]

# %%
v
# Out:
#               Position Domesticus            Musculus Castaneus Spretus  \
# 54        chr1:3007264          T                   T         T       G
# 376       chr1:3047329          T                   T         T       C
# 377       chr1:3047444          T                   T         T       C
# 773       chr1:3095359          G                   G         G       A
# 774       chr1:3095392          T                   T         T       C
# ...                ...        ...                 ...       ...     ...
# 19301938  chrY:2434083          A                   A         A       G
# 19301941  chrY:2434362          G                   G         G       A
# 19302020  chrY:4381141          T  T,0.75,12;A,0.25,4         T       G
# 19302033  chrY:6885219          C                   C         C       G
# 19302112  chrY:9691895          A                   A         A       C
#
#          Caroli Pahari Derived  PhyloP447 NearestGene  NearestDist  SpecSup447
# 54            G      G  MusDer      0.809        Xkr4       663439       164.0
# 376           C      C  MusDer      0.071        Xkr4       623374       299.0
# 377           C      C  MusDer     -1.948        Xkr4       623259       313.0
# 773           A      A  MusDer      0.392        Xkr4       575344       439.0
# 774           C      .  MusDer      0.561        Xkr4       575311       426.0
# ...         ...    ...     ...        ...         ...          ...         ...
# 19301938      G      G  MusDer      0.000      Gm6026       164016       342.0
# 19301941      A      A  MusDer      0.455      Gm6026       163737       432.0
# 19302020      G      A  MusDer      0.120      Gm8521       520913       365.0
# 19302033      G      G  MusDer      2.930     Gm20830        30898       370.0
# 19302112      C      T  MusDer      0.118     Gm20821        90485       365.0
#
# [3420072 rows x 12 columns]

# %%
asymptotic_unfold_cutoff(v, vv, start = 0.1, dn_cut = 0.0001, to_plot_curve = True, cuttt = 0.95)
# Out:
# C:\Users\astar\anaconda3\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# (0.08164792241499677,
#     AF bin     Alpha  Cutoff               [[dc1, du1], [pc1, pu1]]  \
#  0     0.2 -0.244543   2.515  [[138709, 3281363], [54204, 1030380]]
#  1     0.3 -0.153641   2.429   [[149149, 3270923], [38886, 739116]]
#  2     0.4 -0.089997   2.361   [[157517, 3262555], [24427, 464245]]
#  3     0.5 -0.052649   2.318   [[162834, 3257238], [24209, 460080]]
#  4     0.6 -0.019682   2.278   [[167782, 3252290], [17918, 340586]]
#  5     0.7  0.011220   2.242   [[172737, 3247335], [16616, 315967]]
#  6     0.8  0.042592   2.208   [[178143, 3241929], [19917, 378553]]
#  7     0.9  0.064121   2.186   [[182093, 3237979], [19166, 364286]]
#
#                  [[dc2, du2], [pc2, pu2]]  Num Poly in Bin
#  0  [[138822, 3281250], [54254, 1030330]]          1084584
#  1   [[149281, 3270791], [38910, 739092]]           778002
#  2   [[157629, 3262443], [24452, 464220]]           488672
#  3   [[162950, 3257122], [24230, 460059]]           484289
#  4   [[167916, 3252156], [17929, 340575]]           358504
#  5   [[172879, 3247193], [16635, 315948]]           332583
#  6   [[178313, 3241759], [19933, 378537]]           398470
#  7   [[182258, 3237814], [19196, 364256]]           383452  )

# %%
v, yvalls = read_missense(path = "./", maf_cut = 0.1, spec_sup = 250)
yvalls = unfold_missense(yvalls)

v2, yvalls2 = read_noncoding_data_fast(path = "./", maf_cut = 0.1, spec_sup = 250)
yvalls2 = add_unfold(yvalls2)

v3, yvalls3 = read_utr(path = "./", maf_cut = 0.1, spec_sup = 250)
yvalls3 = unfold_utr(yvalls3)

v = pd.concat([v, v2, v3])
yvalls = pd.concat([yvalls, yvalls2, yvalls3])

asymptotic_unfold_cutoff(v, yvalls, start = 0.1, dn_cut = 0.00001, to_plot_curve = True, cuttt = 0.95)
# Out:
# (29874, 12)
# (29720, 12)
# (29720, 12)
# (26661, 12)
# C:\Users\astar\PosSelect_ForPub\PosSelect_Functions_Old.py:651: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yvalls_alt["UnfoldedMAF"] = 1-yvalls_alt["MAFMaxAcrossAncestry"]
# C:\Users\astar\PosSelect_ForPub\PosSelect_Functions_Old.py:652: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yvalls_ref["UnfoldedMAF"] = yvalls_ref["MAFMaxAcrossAncestry"]
# (10748899, 6)
# (5642872, 6)
# (5642872, 6)
# C:\Users\astar\PosSelect_ForPub\PosSelect_Functions_Old.py:559: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yvalls_alt["UnfoldedMAF"] = 1-yvalls_alt["MAFMaxAcrossAncestry"]
# C:\Users\astar\PosSelect_ForPub\PosSelect_Functions_Old.py:560: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yvalls_ref["UnfoldedMAF"] = yvalls_ref["MAFMaxAcrossAncestry"]
# C:\Users\astar\PosSelect_ForPub\PosSelect_Functions_Old.py:660: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   vv = pd.read_csv("HumPoly_UTR_Final.bed", sep = "\t")
# C:\Users\astar\PosSelect_ForPub\PosSelect_Functions_Old.py:668: DtypeWarning: Columns (1,2) have mixed types. Specify dtype option on import or set low_memory=False.
#   p447 = pd.read_csv("447/HumChp_UTR_Final_NewPhyloP447.txt", sep = "\t").set_index("Position")
# C:\Users\astar\PosSelect_ForPub\PosSelect_Functions_Old.py:672: DtypeWarning: Columns (1,2) have mixed types. Specify dtype option on import or set low_memory=False.
#   p447 = pd.read_csv("447/HumPoly_UTR_Final_NewPhyloP447.txt", sep = "\t").set_index("Position")
# (163579, 10)
# (162441, 10)
# (162441, 10)
# (162441, 10)
# (120678, 10)
# C:\Users\astar\PosSelect_ForPub\PosSelect_Functions_Old.py:754: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yvalls_alt["UnfoldedMAF"] = 1-yvalls_alt["MAFMaxAcrossAncestry"]
# C:\Users\astar\PosSelect_ForPub\PosSelect_Functions_Old.py:755: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yvalls_ref["UnfoldedMAF"] = yvalls_ref["MAFMaxAcrossAncestry"]
# C:\Users\astar\anaconda3\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\astar\PosSelect_ForPub\PosSelect_Functions_Old.py:145: RuntimeWarning: invalid value encountered in log
#   return a + d*np.log(x + c)
# (0.008376130061835244,
#     AF bin     Alpha  Cutoff              [[dc1, du1], [pc1, pu1]]  \
#  0     0.2 -0.139051   2.164  [[255657, 5534498], [47790, 908157]]
#  1     0.3 -0.105475   2.136  [[262889, 5527266], [27729, 527404]]
#  2     0.4 -0.052615   2.088  [[275540, 5514615], [20131, 382660]]
#  3     0.5 -0.039546   2.075  [[279043, 5511112], [15838, 300934]]
#  4     0.6 -0.024870   2.061  [[282723, 5507432], [12655, 240517]]
#  5     0.7 -0.011830   2.048  [[286239, 5503916], [10715, 203589]]
#  6     0.8 -0.022240   2.059   [[283308, 5506847], [9296, 176755]]
#  7     0.9  0.002639   2.034   [[290079, 5500076], [8958, 170277]]
#
#                 [[dc2, du2], [pc2, pu2]]  Num Poly in Bin
#  0  [[255927, 5534228], [47829, 908118]]           955947
#  1  [[263142, 5527013], [27758, 527375]]           555133
#  2  [[275828, 5514327], [20142, 382649]]           402791
#  3  [[279304, 5510851], [15856, 300916]]           316772
#  4  [[283013, 5507142], [12666, 240506]]           253172
#  5  [[286545, 5503610], [10723, 203581]]           214304
#  6   [[283602, 5506553], [9305, 176746]]           186051
#  7   [[290343, 5499812], [8964, 170271]]           179235  )

# %%
v
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 v
#
# NameError: name 'v' is not defined
